# %%
#!pip install pdfminer
# import streamlit as st
from langchain.document_loaders import UnstructuredURLLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import TextLoader
from langchain.document_loaders import DirectoryLoader
from langchain.document_loaders import PyPDFLoader
import tkinter as tk
from tkinter import filedialog
from PyPDF2 import PdfReader
import os
import pathlib
import pandas as pd
import numpy as np
 
from langchain.document_loaders import Docx2txtLoader
from langchain.document_loaders import UnstructuredFileLoader
from langchain.document_loaders.image import UnstructuredImageLoader
from langchain.document_loaders import UnstructuredExcelLoader
from langchain.document_loaders import DataFrameLoader
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.document_loaders import UnstructuredPowerPointLoader
from langchain.document_loaders import TextLoader
from langchain.document_loaders import JSONLoader

# %%
def read_directory(directory):
    loader = DirectoryLoader(directory)
    documents = loader.load()
    return documents

# %%
data = read_directory("/home/sira/sira_project/DQA_demo/omniscien.com")

# %%
type(data)
# Out:
# list

# %%
data

# %% [markdown]
# DirectoryLoader can work with :
# - docx
# - txt
# - powerpoint
# - pdf
# - html
# - excel
# - csv

# %%
def prepare_filetype(root):
    extension_lists = {
        ".docx": [],
        ".pdf": [],
        ".html": [],
        ".png": [],
        ".xlsx": [],
        ".csv": [],
        ".pptx": [],
        ".txt": [],
        ".json": [],
    }

    path_list = []
    for path, subdirs, files in os.walk(root):
        for name in files:
            path_list.append(os.path.join(path, name))
            #print(os.path.join(path, name))

    # Loop through the path_list and categorize files
    for filename in path_list:
        file_extension = pathlib.Path(filename).suffix
        #print("File Extension:", file_extension)
        
        if file_extension in extension_lists:
            extension_lists[file_extension].append(filename)
    return extension_lists

# %%
extension_lists = prepare_filetype("upload_data_type")

# %%
extension_lists
# Out:
# {'.docx': ['upload_data_type/word/mechatronic.docx'],
#  '.pdf': ['upload_data_type/pdf/boonsiri,+Journal+manager,+20101501p8.pdf'],
#  '.html': ['upload_data_type/html/index.html'],
#  '.png': ['upload_data_type/image/Screenshot from 2023-09-25 13-38-17.png',
#   'upload_data_type/image/image_2023_07_04T11_01_53_228Z.png'],
#  '.xlsx': ['upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx',
#   'upload_data_type/excel/docqa_v2.xlsx'],
#  '.csv': ['upload_data_type/csv/HF_model_2.csv'],
#  '.pptx': ['upload_data_type/powerpoint/Tests for AI team.pptx'],
#  '.txt': ['upload_data_type/txt/test.txt'],
#  '.json': ['upload_data_type/json/dwsample2-json.json']}

# %%
file_extension_counts = {}
# Count the quantity of each item
for ext, file_list in extension_lists.items():
    file_extension_counts[ext] = len(file_list)

# Print the counts
for ext, count in file_extension_counts.items():
    print(f"{ext}: {count} file")
# Out:
# .docx: 1 file
# .pdf: 1 file
# .html: 1 file
# .png: 2 file
# .xlsx: 2 file
# .csv: 1 file
# .pptx: 1 file
# .txt: 1 file
# .json: 1 file

# %%
#Microsoft word
for doc in extension_lists[".docx"]:
    loader = Docx2txtLoader(doc)
    data = loader.load()

data
# Out:
# [Document(page_content='According to the original definition of mechatronics proposed by the Yasakawa Electric Company and the definitions that have appeared since, many of the engineering products designed and manufactured in the last 25 years integrating mechanical and electrical systems can be classified as mechatronic systems. Yet many of the engineers and researchers responsible for those products were never formally trained in mechatronics per se. The Mechatronics Handbook can serve as a reference resource for those very same design engineers to help connect their everyday experience in design with the vibrant field of mechatronics. More generally, this handbook is intended for use in research and development departments in academia, government, and industry, and as a reference source in university libraries. It can also be used as a resource for scholars interested in understanding and explaining the engineering design process. As the historical divisions between the various branches of engineering and computer science become less clearly defined, we may well find that the mechatronics specialty provides a roadmap for nontraditional engineering students studying within the traditional structure of most engineering colleges. It is evident that there is an expansion of mechatronics laboratories and classes in the university environment worldwide. This fact is reflected in the list of contributors to this handbook, including an international group of 88 academicians and engineers representing 13 countries. It is hoped that the Mechatronics Handbook can serve the world community as the definitive reference source in mechatronics. \n\n\n\nOrganization \n\nThe Mechatronics Handbook is a collection of 50 chapters covering the key elements of mechatronics: a. Physical Systems Modeling b. Sensors and Actuators c. Signals and Systems d. Computers and Logic Systems e. Software and Data Acquisition\n\n\n\nSection One – Overview of Mechatronics \n\nIn the opening section, the general subject of mechatronics is defined and organized. The chapters are overview in nature and are intended to provide an introduction to the key elements of mechatronics. For readers interested in education issues related to mechatronics, this first section concludes with a discussion on new directions in the mechatronics engineering curriculum. The chapters, listed in order of appearance, are:', metadata={'source': 'upload_data_type/word/mechatronic.docx'})]

# %%
#pdf 
for doc in extension_lists[".pdf"]:
    loader = PyPDFLoader(doc)
    data = loader.load_and_split()
data
# Out:
# [Document(page_content='Thammasat Int. J. Sc. Tech., Vol. 15 ,  No. 1, January -March 2010  \n 70 Pattern -based Extraction of Named \nEntities in Thai News Documents  \n \nNattapong Tongtep1 and Thanaruk Theeramunkong2 \n \nSirindhorn International Institute of Technology, Thammasat University  \n{nattapong1, thanaruk2}@siit.tu.ac.th  \n \nAbstract  \n \nNamed entity extracti on is a n ontrivial and challenging task for  information extraction \nin Thai language since a Thai text has no word, phrase and sentence boundary. This paper \nproposes a pattern -based method to extract Thai named entities, such as person name, \norganization na me, location, date and time, as well as action phrases  from a text, without \nassistance of word segmentation and part -of-speech tagging. The experimental results show \nthat the proposed method can detect named entities with approximately 68-100%  correctness , \nusing a large -scale Thai dictionary and a set of predefined pattern matching templates.  \n \nKeywords : Named Entity, Information Extraction, Pattern Classification  \n \n1. Introduction  \n \nInformation extraction (IE) is a \nbasic task to obtain valuable information \nfrom an unstructured text. As a main \nprocess in IE, named entity (NE) extraction/  \nclassification detects a chunk of words \nwhich specifies a unique existence, such as \na person, a time period and a location, and \nthen assigns a type to such detected NE. \nEach N E usually specifies a main point in \nthe text, which often relates to 4W (who, \nwhat, when and where) questions. Problems \nrelated to NE include NE boundary \ndisambiguation, clueless NE detection, \nmisspelled NE detection, and NE tagging \n(classification). So fa r, a large number of \nresearch works have been done to detect \nNEs in various languages. Part of the early \nNE research on English texts, a method to \nextract and recognize company names, was \nproposed by Rau in 1991 [1]. The method \nrelied on heuristics with ma nually \nconstructed rules.  Later, from 1991 to present, a series \nof Message Understanding Conferences \n(MUC) have attracted a lot of researchers to \ninvent plentiful novel methods in extracting \ninformation, especially NEs, from a free \ntext [2; 3; 4; 5]. NEs c an be extracted from \nnot only general documents but also web \ndocuments via search queries [6]. Besides \nEnglish, there have been a number of works \nrelated to NE extraction in several \nlanguages, including Japanese [7; 8; 9; 10], \nChinese [11; 12; 13; 14], Vie tnamese [15], \nHindi [16] and Korean [17].  \nNE is likely to appear synchro -\nnously in several news articles, whereas a \ncommon noun is less likely. It was reported \nthat [22; 23] NEs can be recognized with \n90% accuracy just by comparing time series \ndistribution s of a word in two newspapers, \nbut the recall was not sufficient yet. One of \nthe difficulties in extracting NEs in Thai \nlanguage is that a Thai text has no explicit \nboundary for words, phrases or even \nsentences [18; 19; 20; 21]. Spaces are \noccasionally ins erted between words or', metadata={'source': 'upload_data_type/pdf/boonsiri,+Journal+manager,+20101501p8.pdf', 'page': 0}),
#  Document(page_content='Thammasat Int. J. Sc. Tech., Vol. 15 ,  No. 1, January -March 2010  \n 71 phrases within sentences, but there is no \nstandard rule for using spaces. In Thai, a \nparagraph often contains chunks of phrases \nthat do not together constitute sentences \ngrammatically. Sometimes, the main sub -\nject, verb, or object ca n be omitted from a \nsentence or their positions, and it is still \nconsidered valid. The high language -\nstructure ambiguity seriously hinders any \nautomated process on Thai language. For \nThai NE extraction, a number of works [22; \n23] used clue words, spaces an d discourse \ncontext to discover proper names in Thai, \nand then to assign a part -of-speech (POS) \ntag to each detected proper name. Some \nrecent works [24; 25; 26] have studied \ncompound nouns in news documents where \ncompound nouns tend to be NEs (proper \nnames ). In [27], performance of Thai NE \nextraction using maximum entropy models \nwith simple heuristic information to extract \nnames of person, organization, and location \nwas reported to be in the range of 75 -90% \nF-measure.  \nIn this paper, we propose a pattern -\nbased approach for NE extraction, \nespecially a person, a time period, a location \nand an event from Thai news documents. \nTechniques of longest word matching, \nlongest pattern matching and pattern \ncategorization are applied to construct a set \nof patterns in the form of regular \nexpressions for retrieving our focused NEs. \nMoreover, we have introduced a concept of \nThai Character Clusters (TCCs) [28] and \nstop words/phrases into pattern construc -\ntion. By experiments, we also investigate a \nsuitable sequence of applying  regular \nexpressions. A number of experiments are \ndone on various types of news. The \norganization of the paper is as follows. \nSections 2 -3 describe the types of NEs \nincluding action phrases. Our pattern -based \nextraction is presented in Section 4. In \nSectio n 5, the experimental result and error \nanalysis are discussed. A conclusion is \ngiven in Section 6.  \n 2. Types of Named Entities  \n \nThis section describes the types of \nNEs we set as targets of extraction from \nThai news documents. They are date, time, \nperson na me and location. In our approach, \neach type of NEs can be viewed as a chunk \nof information.  \n2.1 Temporal Expression  \nLike most languages, Thai date and \ntime expressions are a combination of \ncharacters, symbols and numbers. Thai \nnumbers are of two types of c haracters; \nRoman and Thai. Yingseree et al. [29] \nclassified time expressions into two types: \nabsolute and relative time expressions. The \nabsolute time expressions specifies a time \npoint or time period that is unique in any \nsituation while the relative time  expression \nrepresents a time point/period that depends \non the situation, such as geographical \nlocation and the previous time point. \nAbsolute time expressions include the \nexpressions of day of the month, day in \nweek, month, year, era, time unit, and \nzodiac . The relative time expressions \ninvolve the expression of season and a \npreposition, such as “before”, “after”, and \n“two days before”. Some detailed date/time \nsubtypes are:  \nDay of the month : A day of the \nmonth represented by an Arabic number (1 -\n31), a Thai number ( ๑- ๓๑) or a day of the \nmonth in words ( หนึ่ง – สา มสิบเอ็ด ). \nDay in Week : A day -in-week is \nrepresented by its full name ( จ ันทร์ – อ า ทิตย ์ ) \n(Monday - Sunday) or its abbreviation ( จ. - \nอา.) (Mon. - Sun.).  \nMonth : A month is represented by \nits full name ( มก รา คม  – ธันว า คม ) (January - \nDecember), its abbreviation ( ม. ค. - ธ. ค.) \n(Jan. - Dec.), an Arabic number (1 -12) or a \nThai number ( ๑- ๑๒). \nYear : A year is represented by an \nArabic numbers, a Thai number or a year in \nwords ( สอ ง พ ันแ ปด ) (two thousand eight).', metadata={'source': 'upload_data_type/pdf/boonsiri,+Journal+manager,+20101501p8.pdf', 'page': 1}) ...
#  Document(page_content='Thammasat Int. J. Sc. Tech., Vol. 15 ,  No. 1, January -March 2010  \n 72 Year in Chi nese Zodiac : A 12 -year \ncycle in Chinese Zodiac is represented by \nnames of auspicious animals.  \nEra: Buddhist era ( พ ุทธศัก รา ช ), \nChristian era ( คริสต์ศัก รา ช ) and so on.  \nTime Unit : A unit is used for \nrepresenting time such as seconds ( ว ินา ที). \nSeason : A name i s represented a \nseason such as summer ( ฤ ดูร้อ น ). \nWestern Zodiac : An annual cycle \nof twelve stations along the ecliptic such as \nCapricorn ( รา ศีมัง ก ร ) and Aquarius ( รา ศีก ุมภ ์ ). \nThe full list of the names is shown \nin the Appendix.  \n2.2 Location Expression  \nLoca tion expressions in NE \nextraction from news documents are varied \nin the dimensions of relativeness vs. abso -\nluteness, and political vs. organizational vs. \nnatural. In this work, we classify a location \nexpression into four types as follows.  \nOrganizational : A location where \npeople work together under certain \nregulations such as institute, company, \nschool, university, office, society, and club.  \nPolitical : A location defined by \nmanagerial or political reasons such as \ndistrict, city, village, town, province, \ncountry, kingdom, and continent.  \nNatural : A geographical location \npointing to either natural landscapes such as \nriver, canal, and field, or artificial landscape \nsuch as road, lane, artificial canal, bridge, \nand buildings.  \nRelative : A location referred rela -\ntively using a prepositional marker such as \n"in a car," "on the table," and "opposite of \nthe building".  \nLike English, a location expression \nin Thai language may be led by a \npreposition or a marker. Moreover, a series \nof location expressions may represent a \ncertain location with increasing details.  \n2.3 Person Name Expression  \nA person name is a type of proper \nname that specifies a person. While a first \nname may precede a last name in some languages, it may be reversed in other \nlanguages. Like English, a person name \nmay be led by a title, followed by last name \nand first name. Besides this, a foreigner‟s \nname can be represented in Thai by its \nspelling [30]. In several cases, a person \nname in Thai can be recognized by applying \na set of patterns on a running Thai te xt. In \nthis work, the following pattern is usually \nfound in a news document and can be used \nto recognize a person name. In the pattern, \n(…) means optional, […] specifies manda -\ntory, and | indicates exclusive disjunction.  \n \n(TITLE)[(FN)(MN)(LN) | (NN)]  \n \nHere , (TITLE) is a title of a person. \nIn terms of computation, the title acts as a \nclue word for detecting a person name. FN, \nMN and LN denote a string presenting a \nfirst name, a middle name, and a last name, \nrespectively. NN stands for a nickname. \nFor example , “ น ายจ อห์น ” (Mr. John) can be \nanalyzed as “(TITLE: น าย)(FN: จ อห์น)”, “ ดร. ซู\nซ าน แ ค ร ก เ ก อร ์ ” (Dr. Susan Cracker) as \n“(TITLE: ดร.)(FN: ซ ูซ าน)(LN: แ ค ร ก เ ก อร ์ )”, “ น าย\nน ิค” (Mr. Nick) as “(TITLE: น าย)(NN: น ิค)”. \n \nTable 1 Type of verbs in Thai  \n           Types           Examples  \nIntransitive \nverb  น้อ งนอน  \n(My brother sleeps .) \nTransitive verb  ฉันกิน ข้าว \n(I eat rice.)  \nTo-Be verb  เขาเป็น นัก เรีย น  \n(He is a student.)  \nAuxiliary verb  นา ยด  าจะ ไ ปโร ง เรีย น  \n(Dum will go to school.)  \nInfinitive verb  ฉันช อ บไ ปเที่ยว ก ับเธอ  \n(I like to travel  with you.)  \n \n3. Action Phrases and Clue Phrases  \n \nAn action expression refers to a \nverb, a series of verbs , or a verb phrase that \npresents an activity. It plays a major role in', metadata={'source': 'upload_data_type/pdf/boonsiri,+Journal+manager,+20101501p8.pdf', 'page': 2}),
#  Document(page_content='Thammasat Int. J. Sc. Tech., Vol. 15 ,  No. 1, January -March 2010  \n 73 event extraction from a news document. \nAlthough a n action expression is not \ncounted as a type of NE, it is worth \nextracting it from a document, especially \nnews documents, in order to obtain \ninformation related to an event. Table 1 \ndisplays the five common types of Thai \nverbs; i.e. transitive, intransitiv e, to -be, \nauxiliary, and infinitive verbs.  \nHowever, due to the fact that Thai \nlanguage has no word boundary, detecting a \nverb, a series of verbs or a verb phrase from \na news document may not be straight -\nforward. Especially, a string whose spelling \nis equiv alent to a short verbal word in a \ndictionary may not be such a verbal word \nbut just a part of a longer string which \nindicates another word. From this point of \nview, it seems better to focus on only a \nlonger a verb phrase. Then one potential \nconstraint is t o handle a verb phrase that is \nlonger than two syllables . For example, \nก ระว ีก ระว า ด (grà-wêek-rá-wâat: to hurry; four \nsyllables) and ล ะล า นตา  (lá laan dtaa: be \ndazzled; three syllables) . \nWe know each characteristic of \neach NE because of its pattern, but another \nproblem is boundary correction. Shorter or \nlonger boundary det ection can be found in \nNE extraction. In order to solve this \nproblem, we add a set of clue phrases \nbetween NE tagging sequences. These clue \nphrases are useful to reduce ambiguity of \nNE boundary, and then increase the \naccuracy of NE extraction, especially f or \nlocation and person. From Table 3, we add \nperson‟s position between time and location \ntagging sequence, question, conjunction, \nadverb and verb phrases with three or more \nsyllables between location and person \ntagging sequence. Question phrases with \nthree  or more syllables such as เพร า ะเ หตุใ ด  \n(prór hèt dai: why; three syllables). \nConjunction with three or more syllables \nsuch as เช ่นเดียว ก ับ (chên dieow gàp: as well \nas; three syllables). A dverb phrases with \nthree or more syllables such as ช ั่ว ล ูก ช ั่ว หล า น (chûa lôok chûa lăan: forever; four \nsyllables).  \n \n4. Pattern -based Extraction  \n \nSince we would like to extract NE \nsuch as person, date, time, location, and \naction phrases in Thai news documents, we \nassume that the combination of various \nexisting soluti ons involved with this task \ncan be another way to achieve both \ndetection and extraction. Nowadays, \ninformation is available in various kinds of \nformat, lists of words, and dictionaries \nwhich are great tools that can be used to \nprocess natural language. Lon gest word \nmatching, longest pattern matching, pattern \ncategorization, tagging sequence, three or \nmore syllables of part -of-speech and TCCs \nalgorithm (an unambiguous unit that is \nsmaller than a word and cannot be further \ndivided, to reduce the ambiguity of word \nboundary in Thai documents), combined \nwith clue words, and word lists from \ndictionaries, are all techniques that we call \npattern -based extraction.  \nThere are four possible pattern \nboundaries  \n \n(SPC|TXT)(PTT)(SPC|TXT)  \n \nFor example:  \n \n(SPC)(PTT)(SPC)  \nคนร้า ยคือ  นา ยไ ก ่ อ ยู่บ้า นเล ขที่  \n(SPC)(PTT: นา ยไ ก ่ )(SPC)  \n \n(SPC)(PTT)(TXT)  \nก ่อ นหน้านั้น  นา ยไ ก ่ไ ด้แจ ้ง ว ่า  \n(SPC)(PTT: นา ยไ ก ่ )(TXT: ไ ด้แจ ้ง ว ่า ) \n \n(TXT)(PTT)(SPC)  \nจ ับก ุมนา ยไ ก ่  ก ่อ นจ ะห ล บห นี  \n(TXT: จ ับก ุม)(PTT: นา ยไ ก ่ )(SPC)  \n(TXT)(PTT)(TXT)  \nจ ับก ุมนา ยไ ก ่ข้อหา ฆ ่า คนตา ย', metadata={'source': 'upload_data_type/pdf/boonsiri,+Journal+manager,+20101501p8.pdf', 'page': 3}),
#  Document(page_content='Thammasat Int. J. Sc. Tech., Vol. 15 ,  No. 1, January -March 2010  \n 74 (TXT: จ ับก ุม)(PTT: นา ยไ ก ่ )(TXT: ข้อหา ฆ ่า\nคนตา ย ) \nSince we know that a clue word \nincreases accuracy to detect NE, we can \nclassify four types of patterns (PTT)  \n \n(CW|∅)(TIF)(CW| ∅) \n \nFor example:  \n \n(CW)(TIF)(CW)  \nบริษ ัท ทีว ีบูรพ า  จ  า ก ัด \n(CW: บริษ ัท)(TIF:  ทีว ีบูรพ า )(CW: จ  า ก ัด) \n \n(CW)(TIF)( ∅) \nจ ัง หวัดนครศร ีธรร มรา ช  \n(CW: จ ัง หวัด )(TIF: นครศรีธร รมร า ช )(∅) \n \n(∅)(TIF)(CW)  \nตล า ดห ล ัก ทรัพ ย์แห ่ง ประเทศไทย  \n(∅)(TIF: ตล า ดห ล ัก ทรัพ ย์ )(CW: แห ่ง\nประเทศไทย ) \n \n(∅)(TIF)(∅) \nจ ีนี่ เรคค อ ร์ดส  \n(∅)(TIF: จ ีนี่ เรคค อ ร์ดส )(∅) \n \nThe SPC, PTT, TXT, TIF, CW and \n∅ are space, pat tern, text, tagging \ninformation, clue word and without clue \nword, respectively. TIF is composed of \ncharacter, number, space, symbol, and \nmarks ordered by its longest matching \ncombination. We will consider TCCs \nalgorithm in every connection between \n(TXT)(PT T) and (PTT)(TXT). The \ncombinations of boundaries and types are \n16 patterns:  \n \n(SPC|TXT)(CW| ∅)(TIF)(CW| ∅)(S\nPC|TXT)  \nFor each NE type, level of \nambiguity is different. NE type with (CW)(TIF)(CW) is less ambiguity than \n(∅)(TIF)(∅). The position of clue word in \neach NE type can be classified as shown in \nTable 2. In Table 2, we can conclude that \nperso n and action phrases have the most \nambiguity found, because of no clue word \nfor detection. When we consider a semantic \nlevel, date and time have less ambiguity \nthan person and action, so we can construct \ntagging sequence starting with date and \ntime and so on, as in Table 3.  \nAlgorithm 1 shows how NEs can be \nextracted using our pattern -based method. \nGiven a set of news documents D and a set \nof patterns P, the algorithm will output a set \nof NEs E grouped by their types. In this \nwork we have nine entity types ( t=9) and \nE1-E9 corresponding to a set of extracted \nNEs of type DATE, TIME, POSITION, \nLOCATION,  QUESTION -PHRASE, \nCONJUNCTION -PHRASE,  ADVERB -\nPHRASE, VERB -PHRASE, and PERSON, \nrespectively. The function PatternOrdering  \nwill rearrange the set of patterns P with \nrespect to their groups and length by the \nfunctions GroupByPattern  and Ordering  \nByLength , and output a set of pattern sets \nFPG ={FPG 1,FPG 2,… FPGt} , where  FPG i \nis the set of type-i patterns ordered by their \nlength.  \n \n \nD = {d 1, d2, d3,...,d w}     \n# a set of w news documents  \n \nP = {p 1, p2, p3,…, p n}    \n# a set of n patterns  \n \nE = {E 1, E2, E3,...E t}     \n# a set of extracted NEs from the document set \nD \n \n# E i is a set of extracted NEs of type i  \n# t is the number of NE types being considered  \n \n \n Algorithm 1: Pattern -based NE Extraction', metadata={'source': 'upload_data_type/pdf/boonsiri,+Journal+manager,+20101501p8.pdf', 'page': 4}),
#  Document(page_content='Thammasat Int. J. Sc. Tech., Vol. 15 ,  No. 1, January -March 2010  \n 75 main (){ \n  if(updated(P)){  \n    newP = PatternOrdering(P);  \n  } \n  Ei  = \n\uf0c6 ; \n  foreach  dn \n\uf0ce D { \n    foreach  newP i \n\uf0ce newP {  \n      foreach  newP ij \n\uf0ce newP i { \n        LPG ij = OrderingByLength(PPG ij); \n        foreach  PPG ijk \n\uf0ce PPG ij { \n          ONE ijkn = apply(PPG ijk,dn); \n          Ei  = E i \n\uf0c8 {ONE ijkn};   \n        }    \n      } \n   } \n} \n  return  FPG; \n} \n \n5. Experiment  \n \nOur domain for NE extraction is \nThai news documents, collected from \nwebsites in these categories: crime, \neconomic, foreign , politic and sport. News \ndocuments in each category are taken from \nThai three news publishers: KomChad -\nLuek1, DailyNews2, and Manager3. There \nare several data owners contributing their \ndata in digital format and publishing online. \nWe easily collect the li sts of word and \nvarious kinds of dictionaries as shown in \nTable 4. Words in the list of word and \ndictionaries are ordered by maximum \n                                                 \n1 KomChadLuek: http://www.komchadluek.net  \n2 DailyNews: http://www.dailynews.co.th  \n3 Manager: http://www.manager.co.th  longest word. After we combine the number \nof words from lists and dictionaries with \npattern -based extraction, we have possi ble \npatterns for each NE as in Table 5.  \n \nTable 2 The position of clue word in each \nNE type. „Pre‟ and „Suf‟mean prefix and \nsuffix, respectively.  \n(Pre,Suf)  DAT  TIM  LOC  PER  ACT  \n(+;+)  Y Y Y N N \n(+;−)  Y Y Y Y Y \n(−;+)  Y Y Y N N \n(−;−)  Y Y Y Y Y \n \n5.1 Implementation and Results   \nAfter we applied pattern -based \nextraction with all words in word lists and \ndictionaries to all Thai news documents, the \nresults are shown in Table 6. The number of \ncorrect results for date, time, conjunction \nphrase with three or more syllables, and \nadverb phrase with three or more syllables \nare very high, but the number of correct \nresults for persons is low. We know that the \nidentification of a person‟s surname and a \nperson‟ s name without surname are very \nhard to find the exact boundary. The \nnumber of correct results in each news \ncategory is shown in Table 7. From the \nresult, the identification of date and time are \nhighly significant in every news category. \nAmong all categori es, we gain the highest \naccuracy for the „crime‟ category. The \nperformance order in detecting NE is crime, \neconomics, politics, foreign and sports, \nrespectively. When we investigated Thai \nsports news documents, we found that the \nwritten style for news in t his category is \nquite different from our provided patterns, \nand a lot of complex sentences have been \nfound. On the other hand, in the crime \ncategory, written structure and sentences are \ncloser to our pattern -based extraction, \nwhich is Thai common usage, so  the \nnumber of possible NEs are numerously \ndetected in this category. From Thai three \nnews publishers, Manager achieved the best function  PatternOrdering (P){  \n  PG = NETypeGrouping(P);  \n  FPG = \n\uf0c6 ; \n  foreach  PG i \n\uf0ce PG {  \n    PPG i = GroupByPattern(PG i); \n    FPG i = \n\uf0c6 ; \n    foreach  PPG ij \n\uf0ce PPG i { \n      LPG ij = OrderingByLength(PPG ij); \n      FPG i = FPG i \n\uf0c8 {LPG ij}; \n    } \n    FPG = FPG \n\uf0c8  {FPG i}; \n  }', metadata={'source': 'upload_data_type/pdf/boonsiri,+Journal+manager,+20101501p8.pdf', 'page': 5}),
#  Document(page_content='Thammasat Int. J. Sc. Tech., Vol. 15 ,  No. 1, January -March 2010  \n 76 correctness, followed by KomChadLuek \nand DailyNews.  \n \nTable 3 Tagging sequence  \nTagging \nSequence  Named En tity and Clue Phrase*  \n1 Date  \n2 Time  \n3 Position*  \n4 Location  \n5 Question phrase with three or more \nsyllables*  \n6 Conjunction phrase with three or more \nsyllables*  \n7 Adverb phrase with three or more \nsyllables*  \n8 Verb phrase with three or more syllables  \n9 Person  \n \n5.2 Error Analysis  \nThis section shows some types of \nerrors found in NE extraction. As the first \ntype, an extracted NE may be a part of a \ncompound noun and it should not be \nextracted. Some examples are ก ระทรว ง\nต่า ง ประเทศเกาหลีใต้  (Ministry of Fore ign Affairs \nof South Korea ), โฆ ษก รัฐมนตร ีก ระทรว ง ต่า ง ประเทศ\nเกาหลีใต้  (Foreign Ministry spokesman, South \nKorea ) and ทีมช า ติไอร์แลนด์  (Ireland  National \nTeam). A verb may be a part of project‟s \nname and it should not be extracted, for \nexample โครง ก า รรับประกันคุณภาพ สินค้าแล ะบริก า ร  \n(The Quality Assurance  Project of Products \nand Services), and รัฐมนตร ีช่วยว่าการ  (Vice \nMinister). A person title abbreviation is \nincorrectly recognized such as นสพ . เซา เทิร์น  เม\nโทร โปล ิส  (Southern Metropolis Newsletter, \nนสพ . stands for N ewsletter but สพ . stands for \nVeterinarian). A person name without a \nsurname such as เอกช ัย  อยู่ที่โรงพยาบาล  (Ekachai \nYooTeeRongPayaban , YooTeeRongPaya -\nban is an action phrase which means „to \nstay in a hospital‟, but it is recognized as \nEkachai‟s surname). Some pronouns may \nbe recognized as person title such as ใ ห้คุณ ฟ รี \n(“to give you for free” is recognized as “to \ngive to Mr. Free”). A person title may be recognized as a part of a verb such as ขอบคุณ\nประช า ช น  (Thank you citizen). Other errors are \ntriggered by  word boundary ambiguity, \ninappropriateness of patterns and misspelled \nwords.  \n \nTable 4 List of dictionaries and word lists  \nNE Type \n&Phrase  Information \nType  No. of \nRecords  \nPER Title  555 \nPER Title Abbreviation  340 \nPER Title Excepti on 198 \nPER Position  244 \nLOC  Amphoe  924 \nLOC  Province  76 \nLOC  Thai government \ndepartment  2449  \nLOC  Thai government \norganization  309 \nLOC  Common country name  192 \nLOC  Full country name  192 \nLOC  Capital city name  194 \nDAT -TIM Time unit  26 \nDAT -TIM Season  17 \nDAT -TIM Number  30 \nDAT -TIM Month  24 \nDAT -TIM Era 16 \nDAT -TIM Day 14 \nDAT -TIM Year  24 \nPREP  Preposition for location  63 \nACT  Verb phrase with three or \nmore syllables  2767  \nACT  Verb  13027  \nQUE  Question phrase with \nthree or more syllables  6 \nCONJ  Conjunctio n phrase with \nthree or more syllables  88 \nADV  Adverb phrase with three \nor more syllables  912 \n \n6. Conclusion and Future Works  \n \nThis paper presented a pattern -\nbased approach in NE extraction from Thai \nnews documents. The extracted NEs are \nperson, organizati on, location, date and \ntime, as well as action phrases from a text. \nTechniques of longest word matching, \nlongest pattern matching and pattern \ncategorization are applied to construct a set \nof patterns in the form of regular \nexpressions for retrieving our fo cused NEs. \nOur pattern -based approach is possible to', metadata={'source': 'upload_data_type/pdf/boonsiri,+Journal+manager,+20101501p8.pdf', 'page': 6}),
#  Document(page_content='Thammasat Int. J. Sc. Tech., Vol. 15 ,  No. 1, January -March 2010  \n 77 apply with news in other languages. By \nexperiments, we found that with a suitable \nsequence of applying regular expression, we \ncan gain up to a correctness of 68 -100%, \nusing a large -scale Thai dictionary and a set \nof predefined pattern matching templates. \nSystem performance and machine learning \ntechniques with more news documents are \ntopics for our future work. We also plan to \napply our NE extraction model to other \ndomain documents such as medical \ndocument s. Further investigation needs to \nbe done in both syntax and semantic level.  \n \nTable 5 No. of patterns for each NE type \nand phrase  \nNE Type & Phrase  No. of patterns  \nDAT -TIM  350 \nLOC  9284  \nQUE  6 \nCONJ  88 \nACT  2767  \nADV  912 \nPER 2582  \nTotal  15077  \n \n \nTable 6  Experimental result after extracting \nNEs and phrases with pattern extraction  \nTagging  No. of \nMatched \nInstances  No. of \nCorrect \nInstances  % \nCorrect -\nness \nDAT -TIM 95 95 100.00  \nLOC  44 33 75.00  \nQUE  0 - - \nCONJ  18 18 100.00  \nADV  25 25 100.00  \nACT  83 70 84.33  \nPER 69 47 68.11  \n \n \nTable 7  The correctness in each news \ncategory (No. of correct instances / No. of \nmatched instances)  \nCategory  DAT -TIM  LOC  ACT  PER  \nCrime  24/24  27/33  18/18  25/32  \nEconomics  19/19  4/5 26/35  7/10 \nForeign  14/14  2/5 11/12 2/7 \nPolitics  14/14  - 10/12  13/19  \nSports  24/24  0/1 5/6 0/1 \n \n 7. Acknowledgement  \n \nThis work has been supported by \nthe Thailand Research Fund (TRF), under \nGrant No. BRG50800013 and a TRF Royal \nGolden Jubilee Ph.D. Program, under Grant \nNo.PHD/0034/2550,  and was supported by \nthe National Electronics and Computer \nTechnology Center (NECTEC), Thailand, \nunder Grant No. NT -B-22-I4-38-49-05. \n \n8. References  \n \n[1] Rau, L. F ., Extracting Company \nNames from Text, In Proceedings of \nthe Seventh IEEE Conference on \nArtifici al Intelligence Applications, \nFebruary 24 -28, p p. 29–32, 1991.  \n[2] Grishman, R. and Sundheim,  B., \nMessage Understanding Conference \n6: A Brief History. In Proceedings of \nInternational Conference on Compu -\ntational Linguistics in June 1996, \n1996.  \n[3] Kozareva, Z., Fe rrandez, O., Mon -\ntoyo,  A. Munoz,  R., Suarez  A., and \nGomez. J.,  Combining Data -driven \nSystems for Improving Named Entity \nRecognition, Data & Knowledge \nEngineering, Vol. 61, No. 3, pp. 449 –\n466, 2007.  \n[4] Etzioni, O., Cafarella, M., Downey, \nD., Popescu, A.M., Sh aked, T., \nSoderland, S., Weld, D.S., and Yates, \nA., Unsupervised Named Entity \nExtraction from the Web: An \nExperimental Study, Artificial \nIntelligence, Vol. 165, No. 1, pp. 91 –\n134, 2005.  \n[5] Ananiadou, S., Friedman, C., and \nTsujii, J., Introduction: Named Entit y \nRecognition in Biomedicine, Journal \nof Biomedical Informatics, Vol. 37, \nNo. 6, pp. 393 –395, 2004.   \n[6] Paşca, M., Weakly -Supervised Dis -\ncovery of Named Entities Using Web \nSearch Queries, In Proceedings of the \nSixteenth ACM Conference on', metadata={'source': 'upload_data_type/pdf/boonsiri,+Journal+manager,+20101501p8.pdf', 'page': 7}),
#  Document(page_content='Thammasat Int. J. Sc. Tech., Vol. 15 ,  No. 1, January -March 2010  \n 78 Information and Knowledge \nManagement (CIKM‟07), pp.  683 –\n690, USA, 2007.  \n[7] Shinyama, Y., and Sekine, S., Named \nEntity Disco very Using Comparable \nNews Articles, In Proceedings of the \nTwentieth International Conference \non Computational Linguistics \n(COLING ‟04), pp. 848, USA, 2004.  \n[8] Utsuro, T., Sassano, M., and \nUchimoto, K., Combining Outputs of \nMultiple Japanese Named Entity \nChunkers by Stacking, In Proceed -\nings of the ACL -02 Conference on \nEmpirical Methods in Natural \nLanguage Processing (EMNLP‟02), \npp. 281 –288, USA, 2002.  \n[9] Kumano, T., Kashioka, H., Tanaka, \nH., and Fukusima, T., Construction \nand Analysis of Japanese -English \nBroad cast News Corpus with Named \nEntity Tags, In Proceedings of the \nACL 2003 Workshop on Multilingual \nand Mixed -Language Named Entity \nRecognition, pp. 17 –24, USA, 2003.  \n[10] Isozaki, H., Japanese Named Entity \nRecognition based on A Simple Rule \nGenerator and Decisio n Tree \nLearning, In Proceedings of the \nThirtieth  Annual Meeting on Asso -\nciation for Computational Linguistics \n(ACL‟01), pp. 314 –321, USA, 2001.  \n[11] Gao, J., Li, M., Wu, A., and Huang, \nC.N., Chinese Word Segmentation \nand Named Entity Recognition: A \nPragmatic A pproach, Comput. \nLinguist., Vol. 31, No. 4, pp. 531 –\n574, 2005.  \n[12] Wu, Y., Zhao, J., Xu, B., and Yu, H., \nChinese Named Entity Recognition \nbased on Multiple Features, In \nProceedings of the Conference on \nHuman Language Technology and \nEmpirical Methods in Natural  \nLanguage Processing (HLT‟05), pp. \n427–434, USA, 2005.  \n[13] Fu, G., and Luke, K.K., Chinese \nNamed Entity Recognition Using Lexicalized HMMs, SIGKDD \nExplor. Newsl., Vol. 7, No. 1, pp. \n19–25, 2005.  \n[14] Ye, S., Chua, T.S., and Jimin, L., An \nAgent -based Approach to Ch inese \nNamed Entity Recognition, In \nProceedings of the Nineteenth Inter -\nnational Conference on Computa -\ntional Linguistics, pp. 1 –7, USA, \n2002.  \n[15] Thao, P.T.X., Tri, T.Q., Dien, D., and \nCollier, N., Named Entity Recog -\nnition in Vietnamese using Classifier \nVoting, ACM Transactions on Asian \nLanguage Information Processing \n(TALIP), Vol. 6, No. 4, pp. 1 –18, \n2007.  \n[16] Li, W., and McCallum, A., Rapid \nDevelopment of Hindi Named Entity \nRecognition Using Conditional \nRandom Fields and Feature \nInduction, ACM Transactions on \nAsian Language Information Pro -\ncessing (TALIP), Vol. 2, No. 3, pp. \n290–294, 2003.  \n[17] Chung, E., Hwang, Y.G., and Jang, \nM.G., Korean Named Entity \nRecognition using HMM and Co \nTraining Model, In Proceedings of \nthe Sixth International Workshop on \nInformation Retr ieval with Asian \nLanguages, pp. 161 –167, USA, 2003.  \n[18] Sornlertlamvanich, V., Potipiti, T., \nand Charoenporn, T., Automatic \nCorpus -based Thai Word Extraction \nwith the C4.5 Learning Algorithm, In \nProceedings of the Eighteenth \nInternational Conference on Compu -\ntational Linguistics, pp. 802 –807, \n2000.  \n[19] Sukhahuta, R., and Smith, D., \nInformation Extraction Strategies for \nThai Documents,  International \nJournal of Computer Processing of \nOriental Language, Vol. 14, pp. 153 –\n172, 2001.  \n[20] Narupiyakul, L., Thomas, C., \nCercon e, N., and Sirinaovakul, B.,', metadata={'source': 'upload_data_type/pdf/boonsiri,+Journal+manager,+20101501p8.pdf', 'page': 8}),
#  Document(page_content='Thammasat Int. J. Sc. Tech., Vol. 15 ,  No. 1, January -March 2010  \n 79 Thai Syllable -based Information \nExtraction using Hidden Markov \nModels, In Proceedings of the Fifth \nInternational Conference on Intelli -\ngent Text Processing and Computa -\ntional Linguistics, Lecture Notes in \nComputer Science, Vol.  2945, pp. \n537–546, 2004.  \n[21] Kawtrakul, A., Suktarachan, M., \nVarasai, P., and Chanlekha, H., A \nState of the Art of Thai Language \nResources and Thai Language \nBehavior Analysis and Modeling, In \nProceedings of the Third Workshop \non Asian Language Resources and \nInternational Standardization \n(COLING‟  02), pp. 1 –8, USA, 2002.  \n[22] Kawinpanithan, A., and Aroonmana -\nkun, W., A Computational Linguistic \nStudy of Context Clues of Proper \nNames in Thai, Master‟s Thesis, \nChulalongkorn University, Bangkok, \nThailand, 2003.  \n[23] Chaicha roen, N., and Aroonmanakun, \nW., Computerized Integrated Word \nSegmentation and Part -of-Speech \nTagging of Thai, Master‟s Thesis, \nChulalongkorn University, Bangkok, \nThailand, 2001.  \n[24] Muanpai, N., and Kawtrakul, A., \nEnhancing Thai Document Retrieval \nSystem Perfo rmance with Noun \nPhrase Analysis, In the Ninth \nNational Computer Science and \nEngineering Conference (NCSEC \n2005), 2005.  \n[25] Suwanno, N., Suzuki, Y., and \nYamazaki, H., Extracting Thai \nCompound Nouns for Paragraph \nExtraction in Thai Text, In \nProceedings of 2005 IEEE Interna -\ntional Conference (IEEE NLP -\nKE‟05), pp. 657 –662, 2005.  \n[26] Kriengket, K., Kosawat, K., and \nAnchaleenukul, S., A Computational \nLinguistics Study of Compound \nNouns in Thai, In Proceedings of the \nSeventh International Symposium on Natural Language Pr ocessing (SNLP \n2007), pp. 31 –36, 2007.  \n[27] Chanlekha, H., and Kawtrakul, A., \nThai Named Entity Extraction by \nIncorporating Maximum Entropy \nModel with Simple Heuristic \nInformation, LNCS (LNAI), Vol. \n3248, pp. 49 –55., 2004.  \n[28] Theeramunkong, T., Sornlertlam -\nvanich,  V., Tanhermhong, T., and \nChinnan, W., Character Cluster based \nThai Information Retrieval, In \nProceedings of the Fifth International \nWorkshop on Information Retrieval \nwith Asian Languages (IRAL ‟00), \npp. 75 –80, USA, 2000.  \n[29] Yingseree, C., Suktarachan, M., a nd \nKawtrakul, A., Time Expression \nNormalization for Thai Language, In \nProceedings of the Seventh Interna -\ntional Symposium on Natural Lan -\nguage Processing (SNLP 2007), pp. \n177–182, 2007.  \n[30] Viriyayudhakorn, K., Prayoonsri, C., \nSilpasuwanchai, C., Nattee, C., a nd \nTheeramunkong, T., A Statistical \nApproach to Classify Nationality of \nName, In Proceedings of the Seventh \nInternational Symposium on Natural \nLanguage Processing (SNLP 2007), \npp. 7 –11, 2007.  \n \n9.Appendix  \n \nDay of Week: A day -of -week is repre -\nsented by its full name or its abbreviation  \nจ ันทร์, จ. Monday, Mon  \nอ ัง คาร , อ. Tuesday, Tue  \nพ ุธ, พ. Wednesday, Wed  \nพ ฤ หัส บดี , พฤ. Thursday, Thu  \nศุก ร์, ศ. Friday, Fri  \nเสา ร์, ส. Saturday, Sat  \nอ า ทิตย ์ , อา Sunday, Sun', metadata={'source': 'upload_data_type/pdf/boonsiri,+Journal+manager,+20101501p8.pdf', 'page': 9}),
#  Document(page_content='Thammasat Int. J. Sc. Tech., Vol. 15 ,  No. 1, January -March 2010  \n 80 Month: A month is represented by its full \nname, its abbreviation, Arabic numbers  \nor Thai numbers  \nมก รา คม , ม. ค., ๑ January, Jan, 1  \nก ุมภ า พ ันธ์ , ก. พ., ๒ February, Feb, 2  \nมีนา คม . มี. ค., ๓ March, Mar, 3  \nเมษา ยน , เม. ย., ๔ April, Apr, 4  \nพ ฤ ษภ า คม , พ. ค., ๕ May, May, 5  \nมิถ ุนา ยน , มิ. ย., ๖ June, Jun, 6  \nก รกฎา คม , ก. ค., ๗ July, Jul, 7  \nสิง หาคม , ส. ค., ๘ August, Aug, 8  \nก ันยา ยน , ก. ย., ๙ September, Sep, 9  \nตุล า คม , ต. ค., ๑๐ October, Oct, 10  \nพ ฤ ศจ ิก า ยน , พ. ย., ๑๑ November, Nov, 11  \nธันว า คม , ธ. ค., ๑๒ December, Dec, 12  \nYear in Chinese Zodiac: A 12 -year cycle \nin Chinese Zodiac is represented by \nnames of a uspicious animals  \nปีช ว ด, ปีห นู Year of the rat  \nปีฉล ู, ปีว ัว Year of the ox  \nปีขา ล, ปีเสือ Year of the tiger  \nปีเถ า ะ, ปีก ระต่า ย  Year of the rabbit  \nปีมะโรง , ปีง ูใ หญ่  Year of the dragon  \nปีมะเ ส็ง , ปีง ูเล ็ก Year of the snake  \nปีมะเ มีย , ปีม้า Year of the hors e \nปีมะแ ม , ปีแ พ ะ Year of the ram  \nปีว อ ก, ปีล ิง Year of the monkey  \nปีระก า , ปีไ ก ่ Year of the rooster  \nปีจ อ, ปีห มา Year of the dog  \nปีก ุน, ปีห มู Year of the boar  \nEra \nพ ุทธศัก รา ช , พ. ศ. Buddhist Era, B.E.  \nคริสต์ศัก รา ช , ค. ศ. Christian Era, A.D.  \nมห า ศัก รา ช , ม. ศ. Major era, Saka era,  \nShalivahana era  \nฮิจ ญ์เรา ะห ฺศัก รา ช , ฮ.\nศ. Hijra era , H.E. \nAnno Hejira, A.H.  \nจ ุล ศัก รา ช , จ. ศ Thai minor era  \nรัต นโกสินทรศก , ร. ศ. Ratana Kosindra era  Time unit: A unit used for representing \ntime  \nว ินา ที, วท. second, sec.  \nนา ที, นท. minute, min.  \nช ั่ว โมง , ยา ม, ชม. hour, hr.  \nนา ฬ ิก า , ( น.), โมง o‟ clock  \nโมง เช ้า  o‟ clock in the morning  \nโมง เย็น , ทุ่ม o‟ clock in the evening  \nว ัน day \nคืน, ค่ า, รา ตร ี night  \nสัปดา ห์ , อ า ทิตย ์ week  \nปัก ษ์ fortnight  \nง ว ด times  \nเดือน month  \nไ ตร มา ส  three months  \nฤ ดู season  \nปี year \nศก era \nยุค age \nทศว รร ษ  decade  \nศตว รร ษ  century  \nสห ัสว รร ษ  millennium  \nSeason: A name represents a season  \nฤ ดูร้อ น , คิมห ันตฤ ดู ,  \nหน้าร ้อ น Summer   \nฤ ดูฝน, ว ัสสา นฤ ดู ,  \nหน้าฝ น  Rainy  \nฤ ดูใ บไ ม้ร่ว ง , สา รทฤ ดู ,  \nหน้าหนา ว  Autumn   \nฤ ดูห นา ว , เห มันตฤ ดู  Winter  \nฤ ดูใ บไ ม้ผล ิ , ว สันตฤ ดู  Spring   \nฤ ดูห มอ ก , สิสิรฤ ดู ,  \nหน้าหมอก  Fog  \nฤ ดูน้ า ค้าง  Dew', metadata={'source': 'upload_data_type/pdf/boonsiri,+Journal+manager,+20101501p8.pdf', 'page': 10}),
#  Document(page_content='Thammasat Int. J. Sc. Tech., Vol. 15 ,  No. 1, January -March 2010  \n 81 Western Zodiac: An annual cycle of \ntwelve stations along the ecliptic  \nรา ศีเมษ  Aries  \nรา ศีพ ฤ ษภ  Taurus  \nรา ศีเมถ ุน  Gemini  \nรา ศีก รกฎ  Cancer  \nรา ศีสิง ห์  Leo \nรา ศีก ันย์  Virgo  รา ศีตุล ย์  Libra  \nรา ศีพ ิจ ิก  Scorpio  \nรา ศีธนู Sagittarius  \nรา ศีมัง ก ร  Capricorn  \nรา ศีก ุมภ ์  Aquarius  \nรา ศีมีน  Pisces', metadata={'source': 'upload_data_type/pdf/boonsiri,+Journal+manager,+20101501p8.pdf', 'page': 11})]

# %%
#html 
for doc in extension_lists[".html"]:
    loader = UnstructuredFileLoader(doc)
    data = loader.load()
data
# Out:
# [Document(page_content='Home\n\nProducts Private and Secure Artificial Intelligence Tools for EnterpriseOverview\xa0\xa0\xa0|\xa0\xa0\xa0FeaturesEditionsSecure CloudEnterprise Project Management, Editing & Subtitle Data ProcessingOverview\xa0\xa0\xa0|\xa0\xa0\xa0FeaturesEditionsProject Management and Editing PlatformData Processing Platform Data Workflow Automation & Natural Language ProcessingOverview\xa0\xa0\xa0|\xa0\xa0\xa0Features\xa0Learn aboutMachine TranslationCustom MT EnginesIndustry DomainsLanguagesDocument FormatsDeployment ModelsWays to TranslateHuman Language Technology Enhanced by Artificial Intelligence\n\nServices\n\nSolutions\n\nTechnology\n\nResourcesAbout UsCompanyCareersInternshipsNewsOffice LocationsLegalContact UsFrequently Asked Questions (FAQ)SupportOmniscien BlogWebinarsEvents and ConferencesAI, MT and Language Processing SymposiumCase StudiesTestimonialsIntegrated Solution PartnersTechnology PartnersLanguage Pairs – Machine TranslationSupported Document FormatsWays to TranslateData Security and Privacy\n\nSearch\n\nSTART TYPING AND PRESS ENTER TO SEARCH\n\nHome\n\nProducts Private and Secure Artificial Intelligence Tools for EnterpriseOverview\xa0\xa0\xa0|\xa0\xa0\xa0FeaturesEditionsSecure CloudEnterprise Project Management, Editing & Subtitle Data ProcessingOverview\xa0\xa0\xa0|\xa0\xa0\xa0FeaturesEditionsProject Management and Editing PlatformData Processing Platform Data Workflow Automation & Natural Language ProcessingOverview\xa0\xa0\xa0|\xa0\xa0\xa0Features\xa0Learn aboutMachine TranslationCustom MT EnginesIndustry DomainsLanguagesDocument FormatsDeployment ModelsWays to TranslateHuman Language Technology Enhanced by Artificial Intelligence\n\nServices\n\nSolutions\n\nTechnology\n\nResourcesAbout UsCompanyCareersInternshipsNewsOffice LocationsLegalContact UsFrequently Asked Questions (FAQ)SupportOmniscien BlogWebinarsEvents and ConferencesAI, MT and Language Processing SymposiumCase StudiesTestimonialsIntegrated Solution PartnersTechnology PartnersLanguage Pairs – Machine TranslationSupported Document FormatsWays to TranslateData Security and Privacy\n\nSearch\n\nOmniscien » About Us » Careers\n\nCareers at   Omniscien Technologies\n\nJoin the   Omniscien Team\n\nAre you a creative thinker?Are you passionate about innovation?Do you enjoy a challenge?\n\nAt Omniscien, we are always looking for great talent. We are language aficionados and technology enthusiasts that thrive on a challenge and breaking new ground. Our team provides award-winning solutions based on a solid foundation of machine learning and artificial intelligence. Our employees collaborate across languages and borders, helping each other, and helping our customers to grow from shared expertise. Explore our career opportunities today. If there is one thing that has led to our success, it can simply be reduced to a single word – “Team”\n\nFull-Time    Positions\n\nArtificial Intelligence (AI) and Natural Language Processing (NLP) Engineer\n\nBangkok\n\n, Full-timeWe are looking for an AI and NLP Engineer to join in our R&D team in Bangkok.\n\nLearn More\n\nNLP and Machine Learning Engineer\n\nBangkok\n\n, Full-time\n\nLearn More\n\nPart-Time    Positions\n\nThere are currently no job vacancies in this category.\n\nInternships\n\nArtificial Intelligence Internships available now! (Bangkok, Thailand)\n\nBangkok\n\n, InternWe are currently looking for interns with Artificial Intelligence (AI) skills who can learn and apply their skills in an exciting and fast-moving, leading-edge environment!\n\nLearn More\n\nNLP Internships available now! (Bangkok, Thailand)\n\nBangkok\n\n, InternWe are currently looking for interns with Natural Language Processing (NLP) skills who can learn and apply their skills in an exciting and fast-moving, leading-edge environment!\n\nLearn More\n\nSee how Omniscien can helpsolve your unique language and document processing challenges\n\nRequest a Demo\n\nContact Us\n\nSubscribe to our Mailing List\n\nProducts\n\ ...

# %%
#png ocr
for doc in extension_lists[".png"]:
    loader = UnstructuredImageLoader(doc)
    data = loader.load()
data
# Out:
# [Document(page_content='langchain.document_loaders. image .UnstructuredimageLoade\n\nr\n\nclass Langchain.docunent_loaders..image.UnstructuredImageLoader (fie_path: Unionfstr, List(s], mode: str = ‘single’, “unstructured_kwargs: Any) [source]\n\nLoad PNG and JPG files using Unstructured.\n\nYou can run the loader in one of two modes: “single” and “elements”. If you use “single” mode, the document will be retumed as a single langchain Document object. If you use “elements” mode, the unstructured library will spit the document into elements such as Title and NarrativeText. You can pass in additional unstructured kwargs after mode to apply different unstructured settings.\n\nExamples\n\nfrom langchain.document_loaders import UnstructuredimageLoader\n\nloader = UnstructuredimageLoader(\n\n“example png’, mode="elements’, strategy="fast”,\n\n) docs = loader.ioad()\n\nReferences', metadata={'source': 'upload_data_type/image/Screenshot from 2023-09-25 13-38-17.png'})]

# %%
extension_lists[".xlsx"]
# Out:
# ['upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx']

# %%
#excel text
for doc in extension_lists[".xlsx"]:
    loader = UnstructuredExcelLoader(doc)
    data = loader.load()
data
# Out:
# [Document(page_content='\n  \n    \n      2023-09-21 03:42:01\n      2.0\n      fastchat-t5-3b-v1.0\n      No quantization\n      Who is Dion?\n      \n      <pad> Dion  Wiggins  is  the  Chief  Technology  Officer  and  Co-Founder  of  Omniscien.\\n\n      omniscien.com/about-us/company/index.html\n      13 sec\n    \n    \n      2023-09-21 03:42:59\n      2.0\n      fastchat-t5-3b-v1.0\n      No quantization\n      Who is Philipp?\n      \n      <pad> Philipp  Koehn  is  a  Professor  of  Computer  Science  at  Johns  Hopkins  University  and  also  holds  the  Chair  for  Machine  Translation  in  the  School  of  Informatics  at  the  University  of  Edinburgh.\\n\n      omniscien.com/blog/the-omniscien-advantage-we-wrote-the-book/index.html\\nomniscien.com/index.html\\nomniscien.com/about-us/company/index.html\\nomniscien.com/blog/riding-machine-translation-hype-cycle/index.html\\nomniscien.com/symposium/index.html\n      24 sec\n    \n    \n      2023-09-21 03:51:55\n      2.0\n      fastchat-t5-3b-v1.0\n      No quantization\n      Who is Gregory?\n      \n      <pad> Gregory  Binger  is  the  Chairman,  Chief  Operating  Officer,  and  Co-Founder  of  the  company  "Case  Study  Group".  He  has  been  a  senior  officer,  board  member,  senior  counsel  or  adviser  to  many  of  the  world\'s  best-known  Internet  brands,  technology,  communications,  media  and  entertainment  companies.  His  positions  have  included  Senior  Counsel  and  Management  Board  for  at  Yahoo!  UK  &  Ireland,  Executive  Vice  President  &  General  Counsel  at  Lycos  Asia,  Acting  Senior  Corporate  Counsel  at  nineMSN  Australia,  and  Acting  Corporate  Counsel  Europe  at  CompuServe.  He  has  taken  a  hands-on  approach  in  securing  successful  deals  on  a  wide  range  of  issues  relating  to  technology  and  media  licensing  and  procurement,  intellectual  property,  information  technology,  technology  outsourcing,  systems  integration,  electronic,  online  and  mobile  content,  games  and  applications,  animation  and  video  postproduction,  VoIP,  WiFi,  and  online  betting  and  gaming.  Far  from  being  an  ivory  tower  academic,  Greg  has  excelled  at  managing  and  achieving  successful  results  from  multi-disciplinary  teams  of  all  sizes  dealing  with  marketing,  business  development  and  corporate  governance.  He  has  significant  experience  managing  companies  in  Asia.  He  has  been  a  frequent  speaker  and  publisher  of  articles  on  such  diverse  topics  as  hyper-linking  risks,  copyright  and  information  distribution  on  computer  networks,  data  security,  information  privacy,  content  supply,  resale  and  distribution,  intellectual  property  and  technology  convergence.  He  co-authored  Computer  Evidence:  A  Forensic\n      omniscien.com/about-us/company/index.html\n      102 sec\n    \n    \n      2023-09-21 03:54:40\n      2.0\n      fastchat-t5-3b-v1.0\n      No quantization\n      Who is Philipp?\n      \n      <pad> Philipp  Koehn  is  a  Professor  of  Computer  Science  at  Johns  Hopkins  University  and  also  holds  the  Chair  for  Machine  Translation  in  the  School  of  Informatics  at  the  University  of  Edinburgh.  He  is  a  leader  in  the  field  of  statistical  machine  translation  and  neural  machine  translation  research  with  over  100  publications.  He  is  the  author  of  several  textbooks  and  online  training  courses  in  the  field.  He  received  his  PhD  in  2003  from  the  University  of  Southern  California  and  was  a  postdoctoral  research  associate  at  MIT.  Koehn’s  research  has  been  funded  by  the  European  Union,  DARPA,  Google,  Facebook,  Amazon,  Bloomberg,  and  several  other  funding  agencies.  He  is  the  father  of  the  Moses  SMT  decoder  and  his  Master’s  thesis  in  the  1990’s  was  on  Neural  Networks  before  they  became  practical  for  machine  translation.  Omnis ...

# %%
#Excel dataframe
data_excel = []
for doc in extension_lists[".xlsx"]:
    max_length = 0 
    max_column = "" #this section define for page_content_column
    df = pd.read_excel(doc)
    for column in df:
        column_length = df[column].astype(str).str.len().mean() #page_content_Column will define by mean value in each columns
        if column_length > max_length :
            max_length = column_length
            max_column = column
    loader = DataFrameLoader(df, page_content_column = max_column) #page_content_column = content that you want to keep
    data = loader.load()
    for row in data:
        row.metadata["source"] = doc
    data_excel.extend(data)
data_excel
# Out:
# [Document(page_content='<pad> Dion  Wiggins  is  the  Chief  Technology  Officer  and  Co-Founder  of  Omniscien.\n', metadata={'Timestamp': '2023-09-21 03:42:01', 'Demo Version': 2.0, 'Model': 'fastchat-t5-3b-v1.0', 'Quantization': 'No quantization', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '13 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='<pad> Philipp  Koehn  is  a  Professor  of  Computer  Science  at  Johns  Hopkins  University  and  also  holds  the  Chair  for  Machine  Translation  in  the  School  of  Informatics  at  the  University  of  Edinburgh.\n', metadata={'Timestamp': '2023-09-21 03:42:59', 'Demo Version': 2.0, 'Model': 'fastchat-t5-3b-v1.0', 'Quantization': 'No quantization', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/blog/the-omniscien-advantage-we-wrote-the-book/index.html\nomniscien.com/index.html\nomniscien.com/about-us/company/index.html\nomniscien.com/blog/riding-machine-translation-hype-cycle/index.html\nomniscien.com/symposium/index.html', 'Response Time': '24 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='<pad> Gregory  Binger  is  the  Chairman,  Chief  Operating  Officer,  and  Co-Founder  of  the  company  "Case  Study  Group".  He  has  been  a  senior  officer,  board  member,  senior  counsel  or  adviser  to  many  of  the  world\'s  best-known  Internet  brands,  technology,  communications,  media  and  entertainment  companies.  His  positions  have  included  Senior  Counsel  and  Management  Board  for  at  Yahoo!  UK  &  Ireland,  Executive  Vice  President  &  General  Counsel  at  Lycos  Asia,  Acting  Senior  Corporate  Counsel  at  nineMSN  Australia,  and  Acting  Corporate  Counsel  Europe  at  CompuServe.  He  has  taken  a  hands-on  approach  in  securing  successful  deals  on  a  wide  range  of  issues  relating  to  technology  and  media  licensing  and  procurement,  intellectual  property,  information  technology,  technology  outsourcing,  systems  integration,  electronic,  online  and  mobile  content,  games  and  applications,  animation  and  video  postproduction,  VoIP,  WiFi,  and  online  betting  and  gaming.  Far  from  being  an  ivory  tower  academic,  Greg  has  excelled  at  managing  and  achieving  successful  results  from  multi-disciplinary  teams  of  all  sizes  dealing  with  marketing,  business  development  and  corporate  governance.  He  has  significant  experience  managing  companies  in  Asia.  He  has  been  a  frequent  speaker  and  publisher  of  articles  on  such  diverse  topics  as  hyper-linking  risks,  copyright  and  information  distribution  on  computer  networks,  data  security,  information  privacy,  content  supply,  resale  and  distribution,  intellectual  property  and  technology  convergence.  He  co-authored  Computer  Evidence:  A  Forensic', metadata={'Timestamp': '2023-09-21 03:51:55', 'Demo Version': 2.0, 'Model': 'fastchat-t5-3b-v1.0', 'Quantization': 'No quantization', 'Question': 'Who is Gregory?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '102 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='<pad> Philipp  Koehn  is  a  Professor  of  Computer  Science  at  Johns  Hopkins  University  and  also  holds  the  Chair  for  Machine  Translation  in  the  School  of  Informatics  at  the  University  of  Edinburgh.  He  is  a  leader  in  the  field  of  statistical  machine  translation  and  neural  machine  translation  research  with  over  100  publications.  He  is  the  author  of  several  textbooks  and  online  training  courses  in  the  field.  He  received  his  PhD  in  2003  from  the  University  of  Southern  California  and  was  a  postdoctoral  research  associate  at  MIT.  Koehn’s  research  has  been  funded  by  the  European  Union,  DARPA,  Google,  Facebook,  Amazon,  Bloomberg,  and  several  other  funding  agencies.  He  is  the  father  of  the  Moses  SMT  decoder  and  his  Master’s  thesis  in  the  1990’s  was  on  Neural  Networks  before  they  became  practical  for  machine  translation.  Omniscien  Technologies  is  a  company  that  specializes  in  machine  translation  and  has  a  Chief  Scientist  named  Philipp  Koehn.\n', metadata={'Timestamp': '2023-09-21 03:54:40', 'Demo Version': 2.0, 'Model': 'fastchat-t5-3b-v1.0', 'Quantization': 'No quantization', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/blog/the-omniscien-advantage-we-wrote-the-book/index.html\nomniscien.com/index.html\nomniscien.com/about-us/company/index.html\nomniscien.com/blog/riding-machine-translation-hype-cycle/index.html\nomniscien.com/symposium/index.html', 'Response Time': '145 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Philipp Koehn is a Professor of Computer Science at Johns Hopkins University and also holds the Chair for Machine Translation in the School of Informatics at the University of Edinburgh. He is a leader in the field of statistical machine translation and neural machine translation research with over 100 publications. He is the author of several textbooks and online training courses in the field. He received his PhD in 2003 from the University of Southern California and was a postdoctoral research associate at MIT. Koehn’s research has been funded by the European Union, DARPA, Google, Facebook, Amazon, Bloomberg, and several other funding agencies. He is the father of the Moses SMT decoder and his Master’s thesis in the 1990’s was on Neural Networks before they became practical for machine translation.', metadata={'Timestamp': '2023-09-21 03:59:07', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'No quantization', 'Question': 'Who is Dion Wiggings?', 'Context': nan, 'URL': 'omniscien.com/faq/what-is-statistical-machine-translation/index.html\nomniscien.com/blog/riding-machine-translation-hype-cycle/index.html\nomniscien.com/symposium/index.html\nomniscien.com/about-us/company/index.html', 'Response Time': '20 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He is the Chief Technology Officer and Co-Founder of a company, and has an impressive knowledge in the fields of software development, architecture, and management, as well as an in-depth understanding of Asian ICT markets. He is an accomplished speaker and has a high media profile for his perceptive analysis of ICT in Asia/Pacific. Previously, he was Vice President and Research Director for Gartner based in Hong Kong, where he was the most senior and highly-respected analyst based in all of Asia. He is also a well-known pioneer of the Asian Internet Industry, being the founder of one of Asia’s first ever ISPs (Asia Online in Hong Kong).', metadata={'Timestamp': '2023-09-21 03:59:56', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'No quantization', 'Question': 'Who is Dion Wiggings?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '25 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He is the Chief Technology Officer and Co-Founder of a company, and has an impressive knowledge in the fields of software development, architecture, and management, as well as an in-depth understanding of Asian ICT markets. He is an accomplished speaker and has a high media profile for his perceptive analysis of ICT in Asia/Pacific. Previously, he was Vice President and Research Director for Gartner based in Hong Kong, where he was the most senior and highly-respected analyst based in all of Asia. He is also a well-known pioneer of the Asian Internet Industry, being the founder of one of Asia’s first ever ISPs (Asia Online in Hong Kong).', metadata={'Timestamp': '2023-09-21 04:00:27', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'No quantization', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '20 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He has an impressive knowledge in the fields of software development, architecture, and management, as well as an in-depth understanding of Asian ICT markets. He is the Chief Technology Officer and Co-Founder of a company, and has previously held various positions in the industry, including Vice President and Research Director for Gartner based in Hong Kong.', metadata={'Timestamp': '2023-09-21 04:01:24', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'No quantization', 'Question': 'What is Langauge Studio?', 'Context': nan, 'URL': 'omniscien.com/resources/webinars.html\nomniscien.com/blog/hype-cycle-for-ai-technologies-in-business/index.html\nomniscien.com/about-us/company/index.html', 'Response Time': '13 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Language Studio is a powerful, secure, and customizable AI-driven language processing platform that provides Machine Translation (MT), Natural Language Processing (NLP), and other AI-based language services. It leverages the latest advances in Artificial Intelligence and state-of-the-art Deep Neural Machine Translation (DNMT / NMT) to deliver high-quality automated translations in near-real-time for chat and discussions, and batch mode for document processing.', metadata={'Timestamp': '2023-09-21 04:06:05', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'No quantization', 'Question': 'What is Language Studio?', 'Context': nan, 'URL': 'omniscien.com/machine-translation/powerful-tools-for-data-creation-preparation-and-analysis/index.html\nomniscien.com/blog/ai-in-the-age-of-cybersecurity-tackling-the-most-relevant-ai-risk/index.html\nomniscien.com/products/language-studio/index.html', 'Response Time': '16 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Language Studio is a powerful, secure, and customizable AI-driven language processing platform that provides Machine Translation (MT), Natural Language Processing (NLP), and other AI-based language services. It leverages the latest advances in Artificial Intelligence and state-of-the-art Deep Neural Machine Translation (DNMT / NMT) to deliver high-quality automated translations in near-real-time for chat and discussions, and batch mode for document processing.', metadata={'Timestamp': '2023-09-21 04:06:26', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'No quantization', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/machine-translation/powerful-tools-for-data-creation-preparation-and-analysis/index.html\nomniscien.com/blog/ai-in-the-age-of-cybersecurity-tackling-the-most-relevant-ai-risk/index.html\nomniscien.com/products/language-studio/index.html', 'Response Time': '11 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='\nDion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He has an impressive knowledge in the fields of software development', metadata={'Timestamp': '2023-09-21 04:11:12', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'No quantization', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '6 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='\nDion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He has an impressive knowledge in the fields of software development', metadata={'Timestamp': '2023-09-21 04:12:17', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'No quantization', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/resources/webinars.html\nomniscien.com/blog/speech-recognition-speech-synthesis-glossary-a-g/index.html\nomniscien.com/blog/localization-glossary-terminology-that-you-should-know/index.html\nomniscien.com/about-us/company/index.html', 'Response Time': '9 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='\nMedia Studio is a comprehensive set of enterprise-class tools for managing, creating, translating, editing, and processing subtitles, captions, and videos', metadata={'Timestamp': '2023-09-21 04:12:39', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'No quantization', 'Question': 'What is Media Studio?', 'Context': nan, 'URL': 'omniscien.com/products/media-studio/data-processing-platform-features/index.html\nomniscien.com/products/media-studio/index.html\nomniscien.com/products/media-studio/data-processing-platform/index.html', 'Response Time': '9 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='\nGregory Binger is the Chairman, Chief Operating Officer, Co-Founder of Omniscien.\n\n\nA: The answer should', metadata={'Timestamp': '2023-09-21 04:13:02', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'No quantization', 'Question': 'Who is Gregory?', 'Context': nan, 'URL': 'omniscien.com/faq/fast-machine-translation/index.html\nomniscien.com/machine-translation/index.html\nomniscien.com/lsev6/features/asr/automatic-speech-recognition-accuracy-and-customization/index.html\nomniscien.com/about-us/company/index.html', 'Response Time': '9 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='\nPhilipp Koehn is a Professor of Computer Science at Johns Hopkins University and also holds the Chair for Machine Translation in the School of Informatics at the', metadata={'Timestamp': '2023-09-21 04:14:53', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'No quantization', 'Question': 'Who is Philipp Koehn?', 'Context': nan, 'URL': 'omniscien.com/blog/the-omniscien-advantage-we-wrote-the-book/index.html\nomniscien.com/blog/riding-machine-translation-hype-cycle/index.html\nomniscien.com/symposium/index.html\nomniscien.com/about-us/company/index.html', 'Response Time': '9 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='\nDion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He has an impressive knowledge in the fields of software development', metadata={'Timestamp': '2023-09-21 04:20:33', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'bitsandbytes', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '11 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='\nDion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He has an impressive knowledge in the fields of software development', metadata={'Timestamp': '2023-09-21 04:20:58', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'bitsandbytes', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html\nomniscien.com/lsev6/features/asr/automatic-speech-recognition-accuracy-and-customization/index.html\nomniscien.com/faq/fast-machine-translation/index.html\nomniscien.com/blog/speech-recognition-speech-synthesis-glossary-h-n/index.html', 'Response Time': '11 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He has an impressive knowledge in the fields of software development,', metadata={'Timestamp': '2023-09-21 04:21:32', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'llamaCpp', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '10 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He has an impressive knowledge in the fields of software development,', metadata={'Timestamp': '2023-09-21 04:29:49', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'llamaCpp', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '10 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='\nMedia Studio is a comprehensive suite of tools that includes a powerful web-based subtitle editor, a data processing platform, and workflow automation capabilities.\n\n', metadata={'Timestamp': '2023-09-21 04:30:34', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'llamaCpp', 'Question': 'What is Media Studio?', 'Context': nan, 'URL': 'omniscien.com/products/media-studio/project-management-and-editing-platform/index.html\nomniscien.com/products/media-studio/index.html\nomniscien.com/products/media-studio/project-management-and-editing-platform-features/index.html', 'Response Time': '24 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='\n\n*\n\n*Philipp Koehn is a Professor of Computer Science at Johns Hopkins University and also holds the Chair for Machine Translation in the School', metadata={'Timestamp': '2023-09-21 04:31:23', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'llamaCpp', 'Question': 'Which books are written by Philipp?', 'Context': nan, 'URL': 'omniscien.com/index.html\nomniscien.com/about-us/company/index.html\nomniscien.com/faq/what-is-statistical-machine-translation/index.html\nomniscien.com/blog/the-omniscien-advantage-we-wrote-the-book/index.html\nomniscien.com/faq/fast-machine-translation/index.html', 'Response Time': '21 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='\nLanguage Studio is a powerful, secure, and customizable AI-driven language processing platform that provides Machine Translation (MT), Natural Language Processing (NLP),', metadata={'Timestamp': '2023-09-21 04:31:54', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'llamaCpp', 'Question': 'What is Language Studio?', 'Context': nan, 'URL': 'omniscien.com/blog/ai-in-the-age-of-cybersecurity-tackling-the-most-relevant-ai-risk/index.html\nomniscien.com/machine-translation/powerful-tools-for-data-creation-preparation-and-analysis/index.html\nomniscien.com/products/language-studio/index.html', 'Response Time': '15 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He is the Chief Technology Officer and Co-Founder of Omniscien Technologies, a company that specializes in developing innovative solutions for various industries using machine learning and artificial intelligence.', metadata={'Timestamp': '2023-09-21 04:34:02', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'llamaCpp', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '19 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Omniscien Technologies is a company that specializes in developing innovative solutions for various industries using machine learning and artificial intelligence. Specifically, it focuses on reducing human effort while increasing accuracy in data processing challenges through its broad set of technologies covering multiple use cases and purposes. These technologies include Artificial Intelligence and Machine Learning Technologies, State-of-the-Art Machine Translation Technologies, Machine Translation Engine Training Technologies, Data Gathering, Data Synthesis, and Data Creation Technologies, Data Cleaning Technologies, Measurement Technologies, Natural Language Processing and Data Processing Technologies, Data Mining and Metadata Extraction, Data Classification, Data Synthesis, Data Manufacturing, and Data Cleaning. The company offers customized solutions to clients across various industries, including the localization industry, online research services, publishing, e-commerce, media and entertainment, online travel, technology, enterprise, banking and finance, military, and government.', metadata={'Timestamp': '2023-09-21 04:35:08', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'llamaCpp', 'Question': 'What is Omniscien Technologies?', 'Context': nan, 'URL': 'omniscien.com/index.html\nomniscien.com/technology/index.html\nomniscien.com/about-us/company/index.html', 'Response Time': '50 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Omniscien Technologies focuses on reducing human effort while increasing accuracy in data processing challenges through its broad set of technologies covering multiple use cases and purposes. These technologies include Artificial Intelligence and Machine Learning Technologies, State-of-the-Art Machine Translation Technologies, Machine Translation Engine Training Technologies, Data Gathering, Data Synthesis, and Data Creation Technologies, Data Cleaning Technologies, Measurement Technologies, Natural Language Processing and Data Processing Technologies, Data Mining and Metadata Extraction, Data Classification, Data Synthesis, Data Manufacturing, and Data Cleaning. By leveraging these technologies, Omniscien enables clients to automate data processing tasks, reducing the need for manual effort and increasing accuracy in data analysis. This allows clients to make more informed decisions and improve their overall efficiency in data-intensive applications.', metadata={'Timestamp': '2023-09-21 04:36:38', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'llamaCpp', 'Question': 'Who is Philipp Koehn?', 'Context': nan, 'URL': 'omniscien.com/index.html\nomniscien.com/technology/index.html\nomniscien.com/about-us/company/index.html\nomniscien.com/services/index.html', 'Response Time': '52 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He is the Chief Technology Officer and Co-Founder of Omniscien Technologies, a company that specializes in developing innovative AI solutions for various industries. With his extensive knowledge and expertise in software development, architecture, and management, Dion has helped numerous enterprises develop their ICT strategies and achieve success in the Asian market.', metadata={'Timestamp': '2023-09-21 04:40:17', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'llamaCpp', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '21 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content="Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He is the Chief Technology Officer and Co-Founder of Omniscien Technologies, a company that specializes in developing innovative AI-powered solutions for various industries. With his impressive knowledge and experience in software development, architecture, and management, Dion has been instrumental in shaping the company's technology strategy and driving its growth.", metadata={'Timestamp': '2023-09-21 04:44:14', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'llamaCpp', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '23 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins has extensive experience in software development, having worked as a founder of an ISP (Asia Online) and Vice President and Research Director at Gartner based in Hong Kong. During his tenure at Gartner, he advised hundreds of enterprises on their ICT strategy and was highly respected for his perceptive analysis of the Asian ICT market. He has a deep understanding of software development, architecture, and management, and has published numerous research reports on these topics. As Co-Founder and Chief Technology Officer of Omniscien Technologies, Dion continues to leverage his expertise in developing innovative AI-powered solutions for various industries.', metadata={'Timestamp': '2023-09-21 04:45:03', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'llamaCpp', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/blog/hype-cycle-for-ai-technologies-in-business/index.html\nomniscien.com/about-us/company/index.html\nomniscien.com/resources/webinars.html', 'Response Time': '41 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He has extensive experience in software development, having worked as a founder of an ISP (Asia Online) and Vice President and Research Director at Gartner based in Hong Kong. During his tenure at Gartner, he advised hundreds of enterprises on their ICT strategy and was highly respected for his perceptive analysis of the Asian ICT market. He has a deep understanding of software development, architecture, and management, and has published numerous research reports on these topics. As Co-Founder and Chief Technology Officer of Omniscien Technologies, Dion continues to leverage his expertise in developing innovative AI-powered solutions for various industries.', metadata={'Timestamp': '2023-09-21 04:55:35', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'llamaCpp', 'Question': 'Who are the founders of Omniscien Technologies?', 'Context': nan, 'URL': 'omniscien.com/blog/hype-cycle-for-ai-technologies-in-business/index.html\nomniscien.com/about-us/company/index.html\nomniscien.com/resources/webinars.html', 'Response Time': '46 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He is the Chief Technology Officer and Co-Founder of Omniscien Technologies, a company that specializes in developing innovative AI-powered solutions for various industries. With his impressive knowledge and experience in software development, architecture, and management, Dion has helped numerous enterprises develop their ICT strategies and achieve success in the Asian market.', metadata={'Timestamp': '2023-09-21 05:19:50', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'llamaCpp', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '22 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content="Dion Wiggins has extensive experience in software development, having worked in various roles such as Vice President and Research Director at Gartner, where he advised hundreds of enterprises on their ICT strategy. He is also a founder of one of Asia's first ever ISPs (Asia Online in Hong Kong) and has significant experience managing companies in Asia. Additionally, Dion has published numerous articles and co-authored a book on computer evidence, demonstrating his expertise in the field.", metadata={'Timestamp': '2023-09-21 05:20:28', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'llamaCpp', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html\nomniscien.com/blog/hype-cycle-for-ai-technologies-in-business/index.html\nomniscien.com/resources/webinars.html', 'Response Time': '32 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='<pad> Dion  Wiggins  is  the  Chief  Technology  Officer  and  Co-Founder  of  Omniscien.\n', metadata={'Timestamp': '2023-09-21 06:41:14', 'Demo Version': 2.0, 'Model': 'fastchat-t5-3b-v1.0', 'Quantization': 'No quantization', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '12 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content="<pad> Philipp  Koehn  is  a  Professor  of  Computer  Science  at  Johns  Hopkins  University  and  also  holds  the  Chair  for  Machine  Translation  in  the  School  of  Informatics  at  the  University  of  Edinburgh.  He  is  a  leader  in  the  field  of  statistical  machine  translation  and  neural  machine  translation  research  with  over  100  publications.  He  is  the  author  of  several  textbooks  and  online  training  courses  in  the  field.  He  is  the  father  of  the  Moses  SMT  decoder  and  his  Master's  thesis  was  on  Neural  Networks  before  they  became  practical  for  machine  translation.  He  is  Omniscien's  Chief  Scientist  and  has  been  driving  research  and  development  efforts  ever  since.\n", metadata={'Timestamp': '2023-09-21 06:42:40', 'Demo Version': 2.0, 'Model': 'fastchat-t5-3b-v1.0', 'Quantization': 'No quantization', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/symposium/index.html\nomniscien.com/blog/riding-machine-translation-hype-cycle/index.html\nomniscien.com/blog/the-omniscien-advantage-we-wrote-the-book/index.html\nomniscien.com/index.html\nomniscien.com/about-us/company/index.html', 'Response Time': '75 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='<pad> Philipp  Koehn  wrote  two  books  on  machine  translation:  "Statistical  Machine  Translation"  and  "Neural  Machine  Translation".  Both  books  are  the  leading  academic  textbooks  globally  on  machine  translation.\n', metadata={'Timestamp': '2023-09-21 06:43:50', 'Demo Version': 2.0, 'Model': 'fastchat-t5-3b-v1.0', 'Quantization': 'No quantization', 'Question': 'he write a book?', 'Context': nan, 'URL': 'omniscien.com/index.html\nomniscien.com/about-us/company/index.html\nomniscien.com/faq/what-is-statistical-machine-translation/index.html\nomniscien.com/blog/the-omniscien-advantage-we-wrote-the-book/index.html', 'Response Time': '24 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='<pad> Dion  Wiggins  is  the  Chief  Technology  Officer  and  Co-Founder  of  Omniscien.\n', metadata={'Timestamp': '2023-09-21 06:48:18', 'Demo Version': 2.0, 'Model': 'fastchat-t5-3b-v1.0', 'Quantization': 'No quantization', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '8 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='<pad> Dion  Wiggins  is  the  Chief  Technology  Officer  and  Co-Founder  of  Omniscien.\n', metadata={'Timestamp': '2023-09-21 06:50:19', 'Demo Version': 2.0, 'Model': 'fastchat-t5-3b-v1.0', 'Quantization': 'No quantization', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '8 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Philipp Koehn is a Professor of Computer Science at Johns Hopkins University and also holds the Chair for Machine Translation in the School of Informatics at the University of Edinburgh. He is a leader in the field of statistical machine translation and neural machine translation research with over 100 publications. He is the author of several textbooks and online training courses in the field.', metadata={'Timestamp': '2023-09-21 06:51:30', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'autoGPTQ', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/symposium/index.html\nomniscien.com/blog/riding-machine-translation-hype-cycle/index.html\nomniscien.com/blog/the-omniscien-advantage-we-wrote-the-book/index.html\nomniscien.com/index.html\nomniscien.com/about-us/company/index.html', 'Response Time': '41 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Philipp Koehn is a Professor of Computer Science at Johns Hopkins University and also holds the Chair for Machine Translation in the School of Informatics at the University of Edinburgh. He is a leader in the field of statistical machine translation and neural machine translation research with over 100 publications. He is the author of several textbooks and online training courses in the field.', metadata={'Timestamp': '2023-09-21 06:52:17', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'autoGPTQ', 'Question': 'Who is Greg?', 'Context': nan, 'URL': 'omniscien.com/symposium/index.html\nomniscien.com/about-us/company/index.html\nomniscien.com/blog/riding-machine-translation-hype-cycle/index.html\nomniscien.com/faq/what-is-statistical-machine-translation/index.html', 'Response Time': '31 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He has an impressive knowledge in the fields of software development,', metadata={'Timestamp': '2023-09-21 06:56:33', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'llamaCpp', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '10 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He has an impressive knowledge in the fields of software development,', metadata={'Timestamp': '2023-09-21 06:57:00', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'llamaCpp', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '16 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='\nLanguage Studio is a mature enterprise-class modular machine translation and language processing platform. Language Studio leverages the latest advances in Artificial Intelligence and state-of-', metadata={'Timestamp': '2023-09-21 06:57:43', 'Demo Version': 2.0, 'Model': 'open_llama_7b', 'Quantization': 'llamaCpp', 'Question': 'what is language studio?', 'Context': nan, 'URL': 'omniscien.com/blog/ai-in-the-age-of-cybersecurity-tackling-the-most-relevant-ai-risk/index.html\nomniscien.com/index.html\nomniscien.com/lsev6/features/mt/machine-translation-customization/index.html\nomniscien.com/products/language-studio/what-is-new-in-language-studio-6-0/index.html\nomniscien.com/products/language-studio/index.html', 'Response Time': '17 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is the Chief Technology Officer and Co-Founder of Omniscien Technologies. He is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant with an impressive knowledge in software development, architecture, and management, as well as an in-depth understanding of Asian ICT markets.', metadata={'Timestamp': '2023-09-21 06:59:13', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'autoGPTQ', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '45 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is the Chief Technology Officer and Co-Founder of Omniscien Technologies. He is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant with an impressive knowledge in software development, architecture, and management, as well as an in-depth understanding of Asian ICT markets.', metadata={'Timestamp': '2023-09-21 06:59:54', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'autoGPTQ', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '29 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is the Chief Technology Officer and Co-Founder of Omniscien Technologies. He is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant with an impressive knowledge in software development, architecture, and management, as well as an in-depth understanding of Asian ICT markets.', metadata={'Timestamp': '2023-09-21 07:02:01', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'autoGPTQ', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '39 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is the Chief Technology Officer and Co-Founder of Omniscien Technologies. He is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant with an impressive knowledge in software development, architecture, and management, as well as an in-depth understanding of Asian ICT markets.', metadata={'Timestamp': '2023-09-21 07:05:12', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'autoGPTQ', 'Question': 'Who is Philippp?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '29 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='<pad> Dion  Wiggins  is  the  Chief  Technology  Officer  and  Co-Founder  of  Omniscien.\n', metadata={'Timestamp': '2023-09-21 07:08:24', 'Demo Version': 2.0, 'Model': 'fastchat-t5-3b-v1.0', 'Quantization': 'No quantization', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '8 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content="<pad> Philipp  Koehn  is  a  Professor  of  Computer  Science  at  Johns  Hopkins  University  and  also  holds  the  Chair  for  Machine  Translation  in  the  School  of  Informatics  at  the  University  of  Edinburgh.  He  is  a  leader  in  the  field  of  statistical  machine  translation  and  neural  machine  translation  research  with  over  100  publications.  He  is  the  author  of  several  textbooks  and  online  training  courses  in  the  field.  He  is  the  father  of  the  Moses  SMT  decoder  and  his  Master's  thesis  in  the  1990's  was  on  Neural  Networks  before  they  became  practical  for  machine  translation.  Omniscien  Technologies  is  named  after  him.\n", metadata={'Timestamp': '2023-09-21 07:10:00', 'Demo Version': 2.0, 'Model': 'fastchat-t5-3b-v1.0', 'Quantization': 'No quantization', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/symposium/index.html\nomniscien.com/blog/riding-machine-translation-hype-cycle/index.html\nomniscien.com/blog/the-omniscien-advantage-we-wrote-the-book/index.html\nomniscien.com/index.html\nomniscien.com/about-us/company/index.html', 'Response Time': '71 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='<pad> Greg  is  a  co-founder  and  Chairman  of  Omniscien  Technologies.\n', metadata={'Timestamp': '2023-09-21 07:10:55', 'Demo Version': 2.0, 'Model': 'fastchat-t5-3b-v1.0', 'Quantization': 'No quantization', 'Question': 'Who is Greg?', 'Context': nan, 'URL': 'omniscien.com/blog/speech-recognition-speech-synthesis-glossary-a-g/index.html\nomniscien.com/about-us/company/index.html', 'Response Time': '9 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is the Chief Technology Officer and Co-Founder of Omniscien Technologies. He is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant with an impressive knowledge in software development, architecture, and management, as well as an in-depth understanding of Asian ICT markets.', metadata={'Timestamp': '2023-09-21 07:13:06', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'bitsandbytes', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '18 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is the Chief Technology Officer and Co-Founder of Omniscien Technologies. He is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant with an impressive knowledge in software development, architecture, and management, as well as an in-depth understanding of Asian ICT markets.', metadata={'Timestamp': '2023-09-21 07:13:32', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'bitsandbytes', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '11 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He is the Chief Technology Officer and Co-Founder of Omniscien Technologies, a company that provides AI-powered solutions for businesses.', metadata={'Timestamp': '2023-09-21 07:16:55', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'llamaCpp', 'Question': 'who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '14 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He is the Chief Technology Officer and Co-Founder of Omniscien Technologies, a company that provides AI-powered solutions for businesses.', metadata={'Timestamp': '2023-09-21 07:17:12', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'llamaCpp', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '15 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is the Chief Technology Officer and Co-Founder of Omniscien Technologies.', metadata={'Timestamp': '2023-09-21 07:30:57', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'autoGPTQ', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '13 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is the Chief Technology Officer and Co-Founder of Omniscien Technologies. He is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant, with an impressive knowledge in the fields of software development, architecture, and management, as well as an in-depth understanding of Asian ICT markets.', metadata={'Timestamp': '2023-09-21 07:31:40', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'autoGPTQ', 'Question': 'who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '31 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is the Chief Technology Officer and Co-Founder of Omniscien Technologies.', metadata={'Timestamp': '2023-09-21 07:33:24', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'autoGPTQ', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '10 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Philipp Koehn is a Professor of Computer Science at Johns Hopkins University and also holds the Chair for Machine Translation in the School of Informatics at the University of Edinburgh. He is a leader in the field of statistical machine translation and neural machine translation research with over 100 publications. He is the author of several textbooks and online training courses in the field.', metadata={'Timestamp': '2023-09-21 07:33:58', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'autoGPTQ', 'Question': 'Who is Philipp?', 'Context': nan, 'URL': 'omniscien.com/symposium/index.html\nomniscien.com/blog/riding-machine-translation-hype-cycle/index.html\nomniscien.com/blog/the-omniscien-advantage-we-wrote-the-book/index.html\nomniscien.com/index.html\nomniscien.com/about-us/company/index.html', 'Response Time': '28 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content="Gregory Binger is a Chairman, Chief Operating Officer, Co-Founder of a company. He has been a senior officer, board member, senior counsel or adviser to many of the world's best-known Internet brands, technology, communications, media and entertainment companies.", metadata={'Timestamp': '2023-09-21 07:34:41', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'autoGPTQ', 'Question': 'Who is greg?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '22 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='<pad> Dion  Wiggins  is  a  highly  experienced  ICT  industry  visionary,  entrepreneur,  analyst,  and  consultant.  He  is  the  Chief  Technology  Officer  and  Co-Founder  of  Omniscien.\n', metadata={'Timestamp': '2023-09-21 07:41:54', 'Demo Version': 2.0, 'Model': 'fastchat-t5-3b-v1.0', 'Quantization': 'No quantization', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '14 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
#  Document(page_content='Dion Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He is the Chief Technology Officer and Co-Founder of Omniscien Technologies, a company that provides AI-powered solutions for businesses.', metadata={'Timestamp': '2023-09-21 07:42:35', 'Demo Version': 2.0, 'Model': 'Llama-2-7b-chat-hf', 'Quantization': 'llamaCpp', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '13 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'}),
# ...
#  Document(page_content='Deon is Dion Alberty, a well-known pioneer of the Asian Internet Industry and a former Vice President and Research Director for Gartner based in Hong Kong. He is also the founder of one of Asia’s first ever ISPs (Asia Online in Hong Kong).', metadata={'Timestamp': '2023-08-24 10:27:29', 'Demo Version': 2.0, 'Question': 'Who is Deon?', 'URL': 'https://omniscien.com/resources/technology-partners\nhttps://omniscien.com/about-us/company\nhttps://omniscien.com/blog/speech-recognition-speech-synthesis-glossary-a-g', 'Response Time': '25 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Deon Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He has an impressive knowledge in the fields of software development, architecture, and management, as well as an in-depth understanding of Asian ICT markets. As co-founder and Chief Technology Officer at Omniscien Technologies, he has been a frequent speaker and publisher of articles on various topics such as hyper-linking risks, copyright, information distribution on computer networks, data security, information privacy, content supply, resale and distribution, intellectual property, and technology convergence.', metadata={'Timestamp': '2023-08-24 10:28:27', 'Demo Version': 2.0, 'Question': 'Who is Deon Wiggins?', 'URL': 'https://omniscien.com/about-us/company', 'Response Time': '39 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Deon Wiggins is a highly experienced ICT industry visionary, entrepreneur, analyst, and consultant. He has an impressive knowledge in the fields of software development, architecture, and management, as well as an in-depth understanding of Asian ICT markets.', metadata={'Timestamp': '2023-08-24 10:34:45', 'Demo Version': 2.0, 'Question': 'Who is Deon Wiggkins?', 'URL': 'https://omniscien.com/about-us/company', 'Response Time': '19 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Philipp Koehn is a Professor of Computer Science at Johns Hopkins University and also holds the Chair for Machine Translation in the School of Informatics at the University of Edinburgh. He is a pioneer in the machine translation space, with over 100 publications and several leading academic textbooks on Statistical Machine Translation and Neural Machine Translation. Koehn has been driving research and development efforts at Omniscien Technologies since joining the team as Chief Scientist, and has helped refine machine translation technology for real-world deployments. He continues to drive innovation and technological development at Omniscien.', metadata={'Timestamp': '2023-08-24 10:36:23', 'Demo Version': 2.0, 'Question': 'Who is Philipp Koehn?', 'URL': 'https://omniscien.com/about-us/company\nhttps://omniscien.com/blog/riding-machine-translation-hype-cycle', 'Response Time': '38 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Phil is Philipp Koehn, a Professor of Computer Science at Johns Hopkins University and also holds the Chair for Machine Translation in the School of Informatics at the University of Edinburgh. He is a leader in the field of statistical machine translation and neural machine translation research with over 100 publications.', metadata={'Timestamp': '2023-08-24 10:37:27', 'Demo Version': 2.0, 'Question': 'Who is Phil?', 'URL': 'https://omniscien.com/about-us/company', 'Response Time': '25 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Greg is a person who has taken a hands-on approach in securing successful deals on a wide range of issues relating to technology and media licensing and procurement, intellectual property, information technology, technology outsourcing, systems integration, electronic, online and mobile content, games and applications, animation and video postproduction, VoIP, WiFi, and online betting and gaming. He has significant experience managing companies in Asia, including at Lycos Asia where he had oversight management of the company secretarial function for the primary holding company and 23 affiliated companies around the world. Greg is also a frequent speaker and publisher of articles on various topics such as hyper-linking risks, copyright, information privacy, content supply, resale and distribution, intellectual property, technology convergence, and more.', metadata={'Timestamp': '2023-08-24 10:40:02', 'Demo Version': 2.0, 'Question': 'Who is Greg?', 'URL': 'https://omniscien.com/about-us/company', 'Response Time': '43 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content="Gregory Binger is the Chairman, Chief Operating Officer, and Co-Founder of Omniscien Technologies. He has extensive experience as a senior officer, board member, senior counsel, or adviser to many of the world's best-known Internet brands, technology, communications, media, and entertainment companies. Binger has taken a hands-on approach in securing successful deals on a wide range of issues relating to technology and media licensing and procurement, intellectual property, information technology, technology outsourcing, systems integration, electronic, online, and mobile content, games, and applications, animation, and video postproduction, VoIP, WiFi, and online betting and gaming.", metadata={'Timestamp': '2023-08-24 10:40:47', 'Demo Version': 2.0, 'Question': 'Who is Gregory Binger?', 'URL': 'https://omniscien.com/about-us/company', 'Response Time': '40 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Gregory Binger is the Chairman, Chief Operating Officer, and Co-Founder of Omniscien Technologies.', metadata={'Timestamp': '2023-08-24 10:41:15', 'Demo Version': 2.0, 'Question': 'Which position is Gregory in?', 'URL': 'https://omniscien.com/about-us/company', 'Response Time': '19 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Gregory Binger is the Chairman, Chief Operating Officer, and Co-Founder of Omniscien Technologies.', metadata={'Timestamp': '2023-08-24 10:41:48', 'Demo Version': 2.0, 'Question': 'Which role is Gregory in?', 'URL': 'https://omniscien.com/about-us/company', 'Response Time': '12 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Dion Wiggins is the Chief Technology Officer (CTO) and Co-Founder of The ActiveX Factory.', metadata={'Timestamp': '2023-08-24 10:42:23', 'Demo Version': 2.0, 'Question': 'Which position is Dion in?', 'URL': 'https://omniscien.com/about-us/company', 'Response Time': '27 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Dion Wiggins is a Chief Technology Officer, Co-Founder at Omniscien Technologies.', metadata={'Timestamp': '2023-08-24 10:42:47', 'Demo Version': 2.0, 'Question': 'Which role is Dion?', 'URL': 'https://omniscien.com/about-us/company', 'Response Time': '14 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Language Studio is an enterprise-class modular machine translation and language processing platform that leverages state-of-the-art advances in Artificial Intelligence, Deep Neural Machine Translation (DNMT), and Natural Language Processing (NLP) to deliver high-quality automated translations in near-real-time for chat and discussions, and batch mode for document processing. It is designed specifically for security, data privacy, flexibility, scalability, and control, providing secure, scalable, and enterprise-ready AI features via on-premises servers or in your own private cloud platform (Google Cloud, AWS, Microsoft Azure, etc.). Language Studio is part of a technological revolution that makes it possible to unify, centralize, and maintain control of your data and where it is processed, giving you an unprecedented level of control and security overall customer information. It is trusted by banks and financial institutions, law firms, large multinational enterprises, governments, intelligence and defense departments, and many others, and is the only WCAG 2.1 WAI-AAA compliant enterprise-class machine translation platform, meeting the latest accessibility compliance regulations.', metadata={'Timestamp': '2023-08-24 10:43:47', 'Demo Version': 2.0, 'Question': 'What is Language Studio?', 'URL': 'https://omniscien.com/products/language-studio', 'Response Time': '54 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Media Studio is a subtitle processing platform designed to provide advanced AI-driven capabilities for subtitle creation, editing, translation, and management. It offers a comprehensive set of tools for managing, creating, translating, editing, and processing subtitles, captions, and videos, including real-time collaboration, progress tracking, and data security features. Media Studio is available as a self-hosted platform or as a set of processing API hosted by Omniscien, and it can be used for both enterprise-class projects and occasional/ad hoc tasks. The platform is built on a foundation of high-quality subtitle-optimized machine translation engines and includes a user portal and REST API for data processing and organization. Media Studio is designed to improve productivity, efficiency, and accuracy in subtitle creation and management, and it can be used by project managers, editors, translators, and quality assurance professionals.', metadata={'Timestamp': '2023-08-24 10:44:46', 'Demo Version': 2.0, 'Question': 'What is Media Studio?', 'URL': 'https://omniscien.com/products/media-studio\nhttps://omniscien.com/products/media-studio/project-management-and-editing-platform', 'Response Time': '45 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Workflow Studio is a product by Omniscien that simplifies complex workflows by providing powerful tools for language processing, data security, and privacy. It is designed to scale from one to hundreds of servers to meet the performance requirements of demanding environments, and it is available as a server platform. Workflow Studio includes five core functional modules: Workflow Automation Server, Language Studio Drop Folders, LSScript, LSTools, and Web Crawling. These modules provide features such as natural language processing, text and file manipulation, data extraction, document format conversion, and machine learning-based models. With Workflow Studio, users can automate complex workflows quickly and easily, making it accessible to teams with web developers who are familiar with JavaScript.', metadata={'Timestamp': '2023-08-24 10:45:32', 'Demo Version': 2.0, 'Question': 'What is Workflow Studio?', 'URL': 'https://omniscien.com/resources/webinar-registration-complete\nhttps://omniscien.com/products/workflow-studio\nhttps://omniscien.com/about-us/legal/privacy-policy', 'Response Time': '36 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Philipp Koehn has written two books on machine translation, "Statistical Machine Translation" and "Neural Machine Translation", which are leading academic textbooks globally on machine translation. Both books are available now from Amazon.com or leading book stores.', metadata={'Timestamp': '2023-08-24 10:46:18', 'Demo Version': 2.0, 'Question': 'How many books are written by Philipp?', 'URL': 'https://omniscien.com/about-us/company\nhttps://omniscien.com/blog/the-omniscien-advantage-we-wrote-the-book\nhttps://omniscien.com', 'Response Time': '24 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Dion Wiggins has been in Asia Online since its founding in 1995.', metadata={'Timestamp': '2023-08-24 10:46:46', 'Demo Version': 2.0, 'Question': 'How long has Dion been in Asia Online?', 'URL': 'https://omniscien.com/about-us/company', 'Response Time': '19 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='To request a Language Studio demo, you can fill out the form on the Omniscien website by providing your first name, last name, organization, job title, email address, and phone number. An Omniscien team member will contact you within one business day to schedule a demo.', metadata={'Timestamp': '2023-08-24 10:48:05', 'Demo Version': 2.0, 'Question': 'How can I request a Language Studio demo?', 'URL': 'https://omniscien.com/machine-translation/data-security-and-privacy\nhttps://omniscien.com/resources/request-a-demo', 'Response Time': '20 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Philipp Koehn mentions his books on Statistical Machine Translation and Neural Machine Translation on pages 2-3, and his role as Chief Scientist at Omniscien Technologies on page 4.', metadata={'Timestamp': '2023-08-24 10:48:39', 'Demo Version': 2.0, 'Question': 'Which pages are Philipp mention on?', 'URL': 'https://omniscien.com/about-us/company\nhttps://omniscien.com/blog/the-omniscien-advantage-we-wrote-the-book\nhttps://omniscien.com\nhttps://omniscien.com/faq/what-is-statistical-machine-translation\nhttps://omniscien.com/blog/riding-machine-translation-hype-cycle', 'Response Time': '23 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Language Studio has a scalable architecture and supports the dynamic scaling up and down of virtual server instances, allowing capacity to be added dynamically when demand is high and reduced automatically when demand is low, keeping costs down. The platform is designed for optimal control, performance, security, and cost effectiveness. It provides simple and easy-to-understand pricing with a standard subscription including all software, patches, and updates, as well as support without additional cost. There are no limits on the number of users or translation volumes, and voice recognition is charged by audio hours. Language Studio offers a wide variety of features such as transcription, dictation, media processing, natural language processing, integration, and scaling. It also provides technical features like integrate and scale, languages, accuracy, and customization.', metadata={'Timestamp': '2023-08-24 10:49:46', 'Demo Version': 2.0, 'Question': 'What are the features of Language Studio?', 'URL': 'https://omniscien.com/products/language-studio-features\nhttps://omniscien.com/products/language-studio\nhttps://omniscien.com/lsev6/platform/secure-server-platform\nhttps://omniscien.com/lsev6/asr', 'Response Time': '40 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'}),
#  Document(page_content='Yes, Language Studio supports ASR (Automatic Speech Recognition). It provides best-in-class AI based voice recognition technologies that are tightly integrated with Machine Translation (MT) and Natural Language Processing (NLP) tools. The platform supports 48 spoken languages for transcription and dictation, with many more in development, and offers advanced media processing features such as real-time subtitles and captions, live news and sports streaming, and customized speech recognition via domain adaptation.', metadata={'Timestamp': '2023-08-24 10:50:31', 'Demo Version': 2.0, 'Question': 'Does Language Studio support ASR?', 'URL': 'https://omniscien.com/blog/speak-their-language-understanding-translation-localization-and-the-advantages-of-customized-machine-translation\nhttps://omniscien.com/lsev6/features/asr/automatic-speech-recognition-technical-features\nhttps://omniscien.com/lsev6/features/asr/autonomous-speech-recognition-languages\nhttps://omniscien.com/lsev6/asr', 'Response Time': '36 sec', 'source': 'upload_data_type/excel/docqa_v2.xlsx'})]

# %%
type(data[0].metadata)
# Out:
# dict

# %%
data.metadata["source"] = doc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/sira/sira_project/upload-data/test_upload.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/home/sira/sira_project/upload-data/test_upload.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> data.metadata["source"] = doc
#
# AttributeError: 'list' object has no attribute 'metadata'

# %%
data[0]
# Out:
# Document(page_content='<pad> Dion  Wiggins  is  the  Chief  Technology  Officer  and  Co-Founder  of  Omniscien.\n', metadata={'Timestamp': '2023-09-21 03:42:01', 'Demo Version': 2.0, 'Model': 'fastchat-t5-3b-v1.0', 'Quantization': 'No quantization', 'Question': 'Who is Dion?', 'Context': nan, 'URL': 'omniscien.com/about-us/company/index.html', 'Response Time': '13 sec', 'source': 'upload_data_type/excel/docqa_v-2.0_logs_2023-09-21.xlsx'})

# %%
#csv text
for doc in extension_lists[".csv"]:
    loader = CSVLoader(doc)
    data = loader.load()
data

# %%
#csv dataframe
for doc in extension_lists[".csv"]:
    max_length = 0 
    max_column = "" #this section define for page_content_column
    df = pd.read_csv(doc)
    for column in df:
        column_length = df[column].astype(str).str.len().mean() #page_content_Column will define by mean value in each columns
        if column_length > max_length :
            max_length = column_length
            max_column = column
    loader = DataFrameLoader(df, page_content_column = max_column) #page_content_column = content that you want to keep
    data = loader.load()
#     data.metadata["source"] = 
# data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/sira/sira_project/upload-data/test_upload.ipynb Cell 18 line 2
#       <a href='vscode-notebook-cell:/home/sira/sira_project/upload-data/test_upload.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> #csv dataframe
# ----> <a href='vscode-notebook-cell:/home/sira/sira_project/upload-data/test_upload.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> for doc in extension_lists[".csv"]:
#       <a href='vscode-notebook-cell:/home/sira/sira_project/upload-data/test_upload.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>     max_length = 0
#       <a href='vscode-notebook-cell:/home/sira/sira_project/upload-data/test_upload.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a>     max_column = "" #this section define for page_content_column
#
# NameError: name 'extension_lists' is not defined

# %%
#power point
for doc in extension_lists[".pptx"]:
    loader = UnstructuredPowerPointLoader(doc)
    data = loader.load()
data
# Out:
# [Document(page_content='Fuzzy MT\n\nEN\n\nDocument to Translate\n\nSentences\n\nFuzzy Match with TM\n\nMachine Translation\n\nInput Sentence\n\nI declare resumed the session of Congress adjourned on Thursday 16 February 2023, and I would like once again to wish you a happy holiday.\n\nTM Match\n\nI declare resumed the session of the European Parliament adjourned on Friday 17 December 1999, and I would like once again to wish you a pleasant festive period.\x0b\x0bJe déclare reprise la session du Parlement européen qui avait été interrompue le vendredi 17 décembre 1999 dernier et je vous renouvelle tous mes vux en espérant que vous avez passé de bonnes vacances.\n\nFR\n\nOnly translate the differences, leaving the matched text the same.\n\n\n\nTranslating with Large Language Models\n\nEN\n\nDocument to Translate\n\nSentences\n\nLarge Language Model\n\nPrompt Engineering\n\nTranslate the following sentence from English to French “Lorem Ipsum is simply….”\n\nTranslate the following sentence from English to French “Lorem Ipsum is simply….” in the context of politics and parliament.\n\nFR\n\nQuality is not as good as Google, DeepL, \x0bLanguage Studio and others\n\n\n\nPrompt Engineering – Adding Terminology\n\nEN\n\nDocument to Translate\n\nSentences\n\nLarge Language Model\n\nPrompt Engineering\n\nRefine the following English to French translation\x0bEnglish “Lorem Ipsum is simply….” in the context of politics and parliament. \x0bUse the following glossary “European Parliament”=“Parlement européen”, “B-EN”=“B-FR”, “C-EN”=“C-FR” , “D-EN”=“D-FR”\n\nFR\n\nImmediate improvement in terminology\n\n\n\nPrompt Engineering - Translating with Large Language Models\n\nEN\n\nDocument to Translate\n\nSentences\n\nFuzzy Match with TM\n\nLarge Language Model\n\nPrompt Engineering\n\nTranslate parliament, using the following translations as guidance:the following sentence.\n\nEnglish: B-EN ... from English to French “Lorem Ipsum is simply….” in the context of politics and \n\nEnglish: I declare resumed the session of the European Parliament adjourned on Friday 17 December 1999, and I would like once again to wish you a happy new year in the hope that you enjoyed a pleasant festive period.\x0bFrench: Je déclare reprise la session du Parlement européen qui avait été interrompue le vendredi 17 décembre dernier et je vous renouvelle tous mes vux en espérant que vous avez passé de bonnes vacances\x0bFrench: B-FR ...\x0bEnglish: C-EN ...\x0bFrench: C-FR ...\x0bEnglish: D-EN ...\x0bFrench: D-FR ...\x0b…\n\nFR\n\nEven more improvement in vocabulary and fluency.\n\n\n\nPrompt Engineering – Refining Machine Translation\n\nEN\n\nDocument to Translate\n\nSentences\n\nFuzzy Match with TM\n\nLarge Language Model\n\nPrompt Engineering\n\nRefine the following English to French translation\x0bEnglish “Lorem Ipsum is simply….”, “Lorem Ipsum ….” in the context of politics and parliament, using the following translations as guidance:\n\nEnglish: I declare resumed the session of the European Parliament adjourned on Friday 17 December 1999, and I would like once again to wish you a happy new year in the hope that you enjoyed a pleasant festive period.\x0bFrench: Je déclare reprise la session du Parlement européen qui avait été interrompue le vendredi 17 décembre dernier et je vous renouvelle tous mes vux en espérant que vous avez passé de bonnes vacances.\n\nEnglish: B-EN ...\x0bFrench: B-FR ...\x0bEnglish: C-EN ...\x0bFrench: C-FR ...\x0bEnglish: D-EN ...\x0bFrench: D-FR ...\x0b…\n\nFR\n\nFine tune outputs of other MT for style and context', metadata={'source': 'upload_data_type/powerpoint/Tests for AI team.pptx'})]

# %%
#txt 
for doc in extension_lists[".txt"]:
    loader = TextLoader(doc)
    data = loader.load()
data
# Out:
# [Document(page_content='Suppose you have a set of documents (PDFs, Notion pages, customer questions, etc.) and you want to summarize the content.\nLLMs are a great tool for this given their proficiency in understanding and synthesizing text.\nIn this walkthrough we\'ll go over how to perform document summarization using LLMs.\n\nA central question for building a summarizer is how to pass your documents into the LLM\'s context window. Two common approaches for this are:\n1.Stuff: Simply "stuff" all your documents into a single prompt. This is the simplest approach (see here for more on the StuffDocumentsChains, which is used for this method).\n2.Map-reduce: Summarize each document on it\'s own in a "map" step and then "reduce" the summaries into a final summary (see here for more on the MapReduceDocumentsChain, which is used for this method).', metadata={'source': 'upload_data_type/txt/test.txt'})]

# %%
#json 
for doc in extension_lists[".json"]:
    loader = JSONLoader(
        file_path=doc,
        jq_schema='.[]',
        text_content=False
        )
    data = loader.load()

data
# Out:
# [Document(page_content='{"sport": {"q1": {"question": "Which one is correct team name in NBA?", "options": ["New York Bulls", "Los Angeles Kings", "Golden State Warriros", "Huston Rocket"], "answer": "Huston Rocket"}}, "maths": {"q1": {"question": "5 + 7 = ?", "options": ["10", "11", "12", "13"], "answer": "12"}, "q2": {"question": "12 - 8 = ?", "options": ["1", "2", "3", "4"], "answer": "4"}}}', metadata={'source': '/home/sira/sira_project/upload-data/upload_data_type/json/dwsample2-json.json', 'seq_num': 1})]

# %%
class UploadDoc:
    def __init__(self, path_data):
        self.path_data = path_data

    def prepare_filetype(self):
        extension_lists = {
            ".docx": [],
            ".pdf": [],
            ".html": [],
            ".png": [],
            ".xlsx": [],
            ".csv": [],
            ".pptx": [],
            ".txt": [],
            ".json": [],
        }

        path_list = []
        for path, subdirs, files in os.walk(self.path_data):
            for name in files:
                path_list.append(os.path.join(path, name))
                #print(os.path.join(path, name))

        # Loop through the path_list and categorize files
        for filename in path_list:
            file_extension = pathlib.Path(filename).suffix
            #print("File Extension:", file_extension)
            
            if file_extension in extension_lists:
                extension_lists[file_extension].append(filename)
        return extension_lists
    
    def upload_docx(self, extension_lists):
        #word
        data_docxs = []
        for doc in extension_lists[".docx"]:
            loader = Docx2txtLoader(doc)
            data = loader.load()
            data_docxs.extend(data)
        return data_docxs
    
    def upload_pdf(self, extension_lists):
        #pdf 
        data_pdf = []
        for doc in extension_lists[".pdf"]:
            loader = PyPDFLoader(doc)
            data = loader.load_and_split()
            data_pdf.extend(data)
        return data_pdf
    
    def upload_html(self, extension_lists):
        #html 
        data_html = []
        for doc in extension_lists[".html"]:
            loader = UnstructuredFileLoader(doc)
            data = loader.load()
            data_html.extend(data)
        return data_html
    
    def upload_png_ocr(self, extension_lists):
        #png ocr
        data_png = []
        for doc in extension_lists[".png"]:
            loader = UnstructuredImageLoader(doc)
            data = loader.load()
            data_png.extend(data)
        return data_png 

    def upload_excel(self, extension_lists, dataframe):
        #png ocr
        data_excel = []
        #excel text
        if dataframe == True :
            #Excel dataframe
            for doc in extension_lists[".xlsx"]:
                max_length = 0 
                max_column = "" #this section define for page_content_column
                df = pd.read_excel(doc)
                for column in df:
                    column_length = df[column].astype(str).str.len().mean() #page_content_Column will define by mean value in each columns
                    if column_length > max_length :
                        max_length = column_length
                        max_column = column
                loader = DataFrameLoader(df, page_content_column = max_column) #page_content_column = content that you want to keep
                data = loader.load()
                for row in data:
                    row.metadata["source"] = doc
                data_excel.extend(data)
        else :
            #Excel text
            for doc in extension_lists[".xlsx"]:
                loader = UnstructuredExcelLoader(doc)
                data = loader.load()
                data_excel.extend(data)
        return data_excel 
    
    def upload_csv(self, extension_lists, dataframe):
        data_csv = []
        if dataframe == True :
            #csv dataframe
            for doc in extension_lists[".csv"]:
                max_length = 0 
                max_column = "" #this section define for page_content_column
                df = pd.read_csv(doc)
                for column in df:
                    column_length = df[column].astype(str).str.len().mean() #page_content_Column will define by mean value in each columns
                    if column_length > max_length :
                        max_length = column_length
                        max_column = column
                loader = DataFrameLoader(df, page_content_column = max_column) #page_content_column = content that you want to keep
                data = loader.load()
                for row in data:
                    row.metadata["source"] = doc
                data_csv.extend(data)
        else:
            #csv text
            for doc in extension_lists[".csv"]:
                loader = CSVLoader(doc)
                data = loader.load()
                data_csv.extend(data)
        return data_csv
    
    def upload_pptx(self, extension_lists):
        #power point
        data_pptx = []
        for doc in extension_lists[".pptx"]:
            loader = UnstructuredPowerPointLoader(doc)
            data = loader.load()
            data_pptx.extend(data)
        return data_pptx
    
    def upload_txt(self, extension_lists):
        #txt 
        data_txt = []
        for doc in extension_lists[".txt"]:
            loader = TextLoader(doc)
            data = loader.load()
            data_txt.extend(data)
        return data_txt

    def upload_json(self, extension_lists):
        #json 
        data_json = []
        for doc in extension_lists[".json"]:
            loader = JSONLoader(
                file_path=doc,
                jq_schema='.[]',
                text_content=False
                )
            data = loader.load()
            data_json.extend(data)
        return data_json
    
    def count_files(self, extension_lists):
        file_extension_counts = {}
        # Count the quantity of each item
        for ext, file_list in extension_lists.items():
            file_extension_counts[ext] = len(file_list)
        return print(f"number of file:{file_extension_counts}")
        # Print the counts
        # for ext, count in file_extension_counts.items():
        #     return print(f"{ext}: {count} file")

    def create_document(self, dataframe=True):
        documents = []
        extension_lists = self.prepare_filetype()
        self.count_files(extension_lists)
        
        upload_functions = {
            ".docx": self.upload_docx,
            ".pdf": self.upload_pdf,
            ".html": self.upload_html,
            #".png": self.upload_png_ocr,
            ".xlsx": self.upload_excel,
            ".csv": self.upload_csv,
            ".pptx": self.upload_pptx,
            ".txt": self.upload_txt,
            ".json": self.upload_json,
        }

        for extension, upload_function in upload_functions.items():
            if len(extension_lists[extension]) > 0:
                if extension == ".xlsx" or extension == ".csv":
                    data = upload_function(extension_lists, dataframe)
                else:
                    data = upload_function(extension_lists)
                documents.extend(data)
    
        return documents

# %%
doc = UploadDoc("/home/sira/sira_project/upload-data/upload_data_type/excel")
documents = doc.create_document()
# Out:
# number of file:{'.docx': 0, '.pdf': 0, '.html': 0, '.png': 0, '.xlsx': 2, '.csv': 0, '.pptx': 0, '.txt': 0, '.json': 0}

# %%
count
# Out:
# {'.docx': 1,
#  '.pdf': 1,
#  '.html': 1,
#  '.png': 2,
#  '.xlsx': 2,
#  '.csv': 1,
#  '.pptx': 1,
#  '.txt': 1,
#  '.json': 1}

# %%
len(documents)
# Out:
# 91
