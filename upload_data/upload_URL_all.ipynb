# %%
from bs4 import BeautifulSoup
import requests
def scrape_url(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        urls = []
        # Customize this part based on the structure of the website
        # Here's an example of extracting URLs from <a> tags
        for link in soup.find_all('a'):
            href = link.get('href')
            if href is not None and href.startswith('http'):
                urls.append(href)
        return urls
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
        return []

# %%
scrape_url("https://blog.experienced.dev/fine-tune-falcon-qlora-langchain/")
# Out:
# ['https://blog.experienced.dev',
#  'https://blog.experienced.dev/',
#  'https://blog.experienced.dev/about/',
#  'https://arxiv.org/abs/2305.14314?ref=blog.experienced.dev',
#  'https://huggingface.co/datasets/truthful_qa?ref=blog.experienced.dev',
#  'https://cloud.vast.ai/?ref=71973',
#  'https://github.com/experienced-dev/notebooks/blob/master/2023_07_15_vast_ai_create_instance_pytorch.ipynb?ref=blog.experienced.dev',
#  'https://colab.research.google.com/github/experienced-dev/notebooks/blob/master/2023_07_15_vast_ai_create_instance_pytorch.ipynb?ref=blog.experienced.dev',
#  'https://blog.experienced.dev/langchain-mpt-30b-chat-with-tgi-on-vast-ai/',
#  'https://cloud.vast.ai/?ref=71973',
#  'https://github.com/experienced-dev/notebooks/blob/master/2023_07_15_falcon_finetune_qlora_langchain.ipynb?ref=blog.experienced.dev',
#  'https://en.wikipedia.org/wiki/List_of_common_misconceptions?ref=blog.experienced.dev#Modern',
# ...

# %%
import requests
from bs4 import BeautifulSoup
 
 
url = 'https://blog.experienced.dev/fine-tune-falcon-qlora-langchain/'
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')
 
urls = []
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# https://blog.experienced.dev
# https://blog.experienced.dev/
# https://blog.experienced.dev/about/
# #/portal/signin
# #/portal/signup
# /author/shibanovp/
# /author/shibanovp/
# https://arxiv.org/abs/2305.14314?ref=blog.experienced.dev
# https://huggingface.co/datasets/truthful_qa?ref=blog.experienced.dev
# https://cloud.vast.ai/?ref=71973
# https://github.com/experienced-dev/notebooks/blob/master/2023_07_15_vast_ai_create_instance_pytorch.ipynb?ref=blog.experienced.dev
# https://colab.research.google.com/github/experienced-dev/notebooks/blob/master/2023_07_15_vast_ai_create_instance_pytorch.ipynb?ref=blog.experienced.dev
# https://blog.experienced.dev/langchain-mpt-30b-chat-with-tgi-on-vast-ai/
# https://cloud.vast.ai/?ref=71973
# https://github.com/experienced-dev/notebooks/blob/master/2023_07_15_falcon_finetune_qlora_langchain.ipynb?ref=blog.experienced.dev
# https://en.wikipedia.org/wiki/List_of_common_misconceptions?ref=blog.experienced.dev#Modern
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin

def get_all_branch_urls(root_url):
    # Initialize a list to store branch URLs
    branch_urls = []

    # Send an HTTP GET request to the root URL
    response = requests.get(root_url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all <a> tags (links) on the page
        links = soup.find_all('a')

        # Iterate through the links
        for link in links:
            # Get the href attribute of the link
            href = link.get('href')

            # Check if the href is not None and is a relative URL
            if href and not urlparse(href).netloc:
                # Construct the absolute URL using urljoin
                absolute_url = urljoin(root_url, href)

                # Add the absolute URL to the list if it's not already in it
                if absolute_url not in branch_urls:
                    branch_urls.append(absolute_url)
                    
    branch_urls = [link for link in branch_urls if link.startswith("https://")]
    return branch_urls

if __name__ == "__main__":
    root_url = "https://towardsdatascience.com"  # Replace with your root URL
    branch_urls = get_all_branch_urls(root_url)
    
    # urls = []
    # # Print the list of branch URLs
    # for url in branch_urls:
    #     print(url)
    #     urls.append(url)

# %%
len(branch_urls)
# Out:
# 0

# %%
https_links = [link for link in branch_urls if link.startswith("https://")]

# %%
branch_urls
# Out:
# ['https://www.w3schools.com/signup/index.php',
#  'https://www.w3schools.com/spaces/index.php',
#  'https://www.w3schools.com/html/default.asp',
#  'https://www.w3schools.com/tags/default.asp',
#  'https://www.w3schools.com/css/default.asp',
#  'https://www.w3schools.com/cssref/default.asp',
#  'https://www.w3schools.com/css/css_rwd_intro.asp',
#  'https://www.w3schools.com/bootstrap/bootstrap_ver.asp',
#  'https://www.w3schools.com/w3css/default.asp',
#  'https://www.w3schools.com/w3css/w3css_references.asp',
#  'https://www.w3schools.com/sass/default.php',
#  'https://www.w3schools.com/sass/sass_functions_string.php',
#  'https://www.w3schools.com/colors/default.asp',
#  'https://www.w3schools.com/colors/colors_fs595.asp',
#  'https://www.w3schools.com/icons/default.asp',
#  'https://www.w3schools.com/icons/icons_reference.asp',
#  'https://www.w3schools.com/graphics/svg_intro.asp',
#  'https://www.w3schools.com/graphics/svg_reference.asp',
# ...
